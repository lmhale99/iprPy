# %% [markdown]
# # Static elastic constants
# This Notebook follows the workflow for setting up, running, and processing the elastic_constants_static calculations.
#
# **Quick Notes:**
#
# - All input scripts take key-value pairs where the "key"s correspond to the calculation's input parameters.
#
# - Multiple calculations are prepared by specifying multiple values for the same key (on separate lines).
#
# - The special "buildcombos" key accesses predefined functions for generating lists of input parameter values for certain sets of keys.  See documentation for more details.

# %% [markdown]
# **Library imports**

# %%
# Standard Python libraries
from __future__ import (absolute_import, print_function,
                        division, unicode_literals)
import os
from datetime import date
from math import floor
from copy import deepcopy

# http://www.numpy.org/
import numpy as np

# https://pandas.pydata.org/
import pandas as pd

# https://bokeh.pydata.org/
import bokeh
import bokeh.plotting
import bokeh.resources
import bokeh.io
import bokeh.models

from DataModelDict import DataModelDict as DM

# https://github.com/usnistgov/atomman
import atomman.unitconvert as uc

# https://github.com/usnistgov/iprPy
import iprPy
print('iprPy version', iprPy.__version__)
# Out:
# iprPy version 0.8.2

# %% [markdown]
# ## 0. Access database

# %% [markdown]
# ### Load database

# %%
database = iprPy.load_database('demo')

# %% [markdown]
# ## 1. Run elastic_constants_static calculations
#
# This calculation evaluates the elastic constants for a crystal using small strain deformations.

# %%
calculation = iprPy.load_calculation('elastic_constants_static')
run_directory = iprPy.load_run_directory('demo_1')

# %% [markdown]
# ### Show calculation's allowed keys
#
# These are the keys that the input script will accept.

# %%
print(calculation.allkeys)
# Out:
# ['lammps_command', 'mpi_command', 'length_unit', 'pressure_unit', 'energy_unit', 'force_unit', 'potential_file', 'potential_content', 'potential_dir', 'load_file', 'load_content', 'load_style', 'family', 'load_options', 'symbols', 'box_parameters', 'a_uvw', 'b_uvw', 'c_uvw', 'atomshift', 'sizemults', 'strainrange', 'energytolerance', 'forcetolerance', 'maxiterations', 'maxevaluations', 'maxatommotion']

# %% [markdown]
# ### Write input script

# %%
input_script = """
# Commands and executables
lammps_command              lmp_mpi
mpi_command                 

# Build load information from relax_dynamic results
buildcombos                 atomicparent load_file parent
parent_record               calculation_crystal_space_group
parent_load_key             unit-cell-atomic-system

# System manipulations
a_uvw                      
b_uvw                      
c_uvw                 
atomshift                   
sizemults                   5 5 5

# Units that input/output values are in
length_unit                 
pressure_unit               
energy_unit                 
force_unit                  

# Run parameters
energytolerance             
forcetolerance              
maxiterations               
maxevaluations              
maxatommotion               
strainrange                  1e-5
strainrange                  1e-6
strainrange                  1e-7
strainrange                  1e-8
"""

with open('input_script.in', 'w') as f:
    f.write(input_script)

# %%
# Parse input script
with open('input_script.in') as f:
    input_dict = iprPy.input.parse(f, singularkeys=calculation.singularkeys)

# %% [markdown]
# ### Add parent_name list using filtered results

# %%
unique_crystals = pd.read_csv('unique_crystals.csv')
print(len(unique_crystals))
# Out:
# 144

# %%
print(list(unique_crystals.keys()))
# Out:
# ['calc_key', 'potential_LAMMPS_key', 'potential_LAMMPS_id', 'potential_key', 'potential_id', 'composition', 'prototype', 'family', 'method', 'transformed', 'E_coh', 'a', 'b', 'c', 'alpha', 'beta', 'gamma']

# %%
unique_crystals = unique_crystals[unique_crystals.potential_LAMMPS_id == '2012--Park-H--Mo--LAMMPS--ipr1']
#unique_crystals = unique_crystals[unique_crystals.composition == '']
#unique_crystals = unique_crystals[unique_crystals.prototype == '']
print(len(unique_crystals))
# Out:
# 35

# %%
input_dict['parent_name'] = unique_crystals.calc_key.tolist()

# %% [markdown]
# ### Prepare calculations

# %%
database.prepare(run_directory, calculation, **input_dict)
database.check_records(calculation.record_style)
# Out:
# In database style local at C:\Users\lmh1\Documents\calculations\ipr\demo :
# - 140 of style calculation_elastic_constants_static
#  - 0 are complete
#  - 140 still to run
#  - 0 issued errors

# %% [markdown]
# ### Run calculations

# %%
database.runner(run_directory)
database.check_records(calculation.record_style)
# Out:
# Runner started with pid 13384

# %%
results_df = database.get_records_df(style=calculation.record_style)
for error in np.unique(results_df[results_df.status=='error'].error):
    print(error)
# Out:
# b'Traceback (most recent call last):
# un.py", line 110, in run
#     output = sp.check_output(mpi_command + lammps_command + extra + [\'-in\'] + script_name)
#   File "C:\\Users\\lmh1\\AppData\\Local\\Continuum\\anaconda3\\lib\\subprocess.py", line 336, in check_output
#     **kwargs).stdout
#   File "C:\\Users\\lmh1\\AppData\\Local\\Continuum\\anaconda3\\lib\\subprocess.py", line 418, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command \'[\'lmp_mpi\', \'-in\', \'cij.in\']\' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "calc_elastic_constants_static.py", line 282, in <module>
#     main(*sys.argv[1:])
#   File "calc_elastic_constants_static.py", line 55, in main
#     dmax = input_dict[\'maxatommotion\'])
#   File "calc_elastic_constants_static.py", line 161, in elastic_constants_static
#     output = lmp.run(lammps_command, lammps_script, mpi_command)
# un.py", line 116, in run
#     raise ValueError(\'Invalid LAMMPS input: \
# %s\' % lines[-2])
# ValueError: Invalid LAMMPS input:
# Last command: read_restart initial.restart
# '

# %% [markdown]
# ## 2. Calculation analysis

# %% [markdown]
# ### Retrieve finished calculation results

# %%
records = database.get_records_df(style='calculation_elastic_constants_static', full=True, flat=False, status='finished')
pot_records = database.get_records_df(style='potential_LAMMPS')

# %% [markdown]
# ### Build raw data

# %%
for record in records.itertuples():

# %% [markdown]
# ### Save raw data

# %%
records
# Out:
#                                                     C    LAMMPS_version error  \
# 0   [[ 1.00178860e+00  5.19970006e-01  5.19970001e...  26 Jan 2017-ICMS   NaN
# 1   [[7.75440013e-01 5.85913566e-01 5.85913566e-01...  26 Jan 2017-ICMS   NaN
# 2   [[9.15509391e-01 5.87837102e-01 4.68786910e-01...  26 Jan 2017-ICMS   NaN
# 3   [[ 1.71884125  0.11664781  0.11664781  0.     ...  26 Jan 2017-ICMS   NaN
# 5   [[1.23002056e+00 3.34497866e-01 3.34497867e-01...  26 Jan 2017-ICMS   NaN
# 6   [[-1.16578046e+01  2.04301977e+02  7.60693662e...  26 Jan 2017-ICMS   NaN
# 7   [[-8.43526260e-01  2.67322314e+00  2.47887670e...  26 Jan 2017-ICMS   NaN
# 8   [[0.9155094  0.58783711 0.46878691 0.         ...  26 Jan 2017-ICMS   NaN
# 41  [[0.76444791 0.57313522 0.57313522 0.         ...  26 Jan 2017-ICMS   NaN
# 42  [[0.96631348 0.53214058 0.53214058 0.         ...  26 Jan 2017-ICMS   NaN
# 43  [[ 5.54094923e-01  4.07284331e-01  5.43924649e...  26 Jan 2017-ICMS   NaN
# 44  [[ 4.89375669e+03  2.97035138e+03  4.14046006e...  26 Jan 2017-ICMS   NaN
# 45  [[ 2.87671789e+04  1.74152366e+04  3.68452915e...  26 Jan 2017-ICMS   NaN
# 46  [[7.72757680e-01 5.69074530e-01 5.69083309e-01...  26 Jan 2017-ICMS   NaN
# 48  [[7.67500361e-01 5.75654281e-01 5.75654281e-01...  26 Jan 2017-ICMS   NaN
# 49  [[0.76995415 0.75609986 0.75609986 0.         ...  26 Jan 2017-ICMS   NaN
# 50  [[7.65292086e-01 5.72414032e-01 5.72414030e-01...  26 Jan 2017-ICMS   NaN
# 51  [[0.76995415 0.75609986 0.75609986 0.         ...  26 Jan 2017-ICMS   NaN
# 52  [[ 1.23002056e+00  3.34497868e-01  3.34497868e...  26 Jan 2017-ICMS   NaN
# 53  [[ 1.23002053e+00  3.34497860e-01  3.34497860e...  26 Jan 2017-ICMS   NaN
# 54  [[ 7.69954157e-01  7.56099867e-01  7.56099867e...  26 Jan 2017-ICMS   NaN
# 55  [[-0.30530641  2.13699062  0.24788738  0.     ...  26 Jan 2017-ICMS   NaN
# 56  [[0.91585672 0.58019485 0.45830022 0.         ...  26 Jan 2017-ICMS   NaN
# 57  [[0.77544001 0.58591356 0.58591356 0.         ...  26 Jan 2017-ICMS   NaN
# 58  [[0.97272378 0.53576464 0.53576464 0.         ...  26 Jan 2017-ICMS   NaN
# 59  [[ 0.55410635  0.40727234  0.54393607  0.     ...  26 Jan 2017-ICMS   NaN
#
#                        family iprPy_version  \
# 0                oqmd-1214769         0.8.2
# 1                 oqmd-676271         0.8.2
# 2                    mp-10597         0.8.2
# 3            Ah--alpha-Po--sc         0.8.2
# 5                 A15--beta-W         0.8.2
# 6                oqmd-1215927         0.8.2
# 7                oqmd-1215571         0.8.2
# 8                    mp-10597         0.8.2
# 9                oqmd-1214858         0.8.2
# 10  A3'--alpha-La--double-hcp         0.8.2
# 11               oqmd-1215571         0.8.2
# 12               oqmd-1215927         0.8.2
# 13               oqmd-1214680         0.8.2
# 14           Ah--alpha-Po--sc         0.8.2
# 15               oqmd-1214858         0.8.2
# 16               oqmd-1215571         0.8.2
# 17                A15--beta-W         0.8.2
# 18               oqmd-1215482         0.8.2
# 19               oqmd-1215482         0.8.2
# 20               oqmd-1214858         0.8.2
# 21                   mp-10597         0.8.2
# 22               oqmd-1214858         0.8.2
# 23               oqmd-1214769         0.8.2
# 24                oqmd-676271         0.8.2
# 25               oqmd-1215125         0.8.2
# 26               oqmd-1214769         0.8.2
# 27               oqmd-1214769         0.8.2
# 28                   mp-10597         0.8.2
# 29           Ah--alpha-Po--sc         0.8.2
# 33  7cdbdee3-8e5a-4e26-9a8d-a0542c0fdb4a
# 34  86dcc776-61ac-4039-b71e-63f559a8482e
# 35  8760e0d6-42f9-4166-9ae6-79be9d6532c6
# 36  8941a918-ccba-4c50-9e3c-17dbbbb03c17
# 38  91d5b1ef-7c71-4ec5-8b7e-ed8ef16d3481
# 39  976a1d67-c29f-4ceb-b5d5-3ffd6b2d8f21
# 40  97e1a2f2-75ac-48bf-a86b-86f66a936b35
# 41  ac5cd725-5628-4633-9698-a7480ecc720d
# 42  b0e1117a-0fe6-4851-b124-ce1bbbf1a824
# 43  bfa2e2b9-a35b-4747-a059-5b6320c830eb
# 44  c957d7fb-6438-49a8-97ae-05e6d8f046a4
# 45  d0dbccd1-3a08-46dc-99ef-3b2aae2dc251
# 46  d7a8b4cf-ecdf-496c-8eda-8fcb1aa6939e
# 48  dd2cc1c7-3953-44db-b7d7-a3b56a90cedc
# 49  de2fe263-1063-4939-9346-9535c66a7f5f
# 50  e171fb90-4955-4734-b63e-1af424e76894
# 51  e24a8b25-cbfc-4ed6-a0d8-2947d2a5bc56
# 52  e8ff9fda-694d-4e83-9ef5-d9a96525b7bc
# 53  eb410cbd-dbcd-4eb2-ab20-6e9bdce74639
# 54  ee616a09-c5e4-43d2-8cfa-378b68e775f0
# 55  f1c50194-1529-4064-bbd0-68fb95cc54dd
# 56  f3618e24-2781-4680-b762-778c43ae1619
# 57  fb79e8a9-7e0e-4e2c-a23e-f1ee8d14dbf2
# 58  fc62e3b6-ea7b-4e09-bc9f-55dd1755f745
# 59  fff2e5c8-666d-4e73-8ee1-49ee31202ec2
#
#                                     load_file                 load_options  \
# 0   e28fe811-3c5f-48f8-afc9-bf4c5eab15ca.json  key unit-cell-atomic-system
# 1   c1ec7d94-51af-442e-a228-1344a6b4bd4d.json  key unit-cell-atomic-system
# 2   8b349f7d-3991-438a-82d9-a54ea4aff2a2.json  key unit-cell-atomic-system
# 3   235949ee-c95e-42d4-811e-97cd38ae26ba.json  key unit-cell-atomic-system
# 5   2e05623b-4aa8-4fa4-9dde-23ea692a264e.json  key unit-cell-atomic-system
# 6   b795f6b7-e112-4955-8aef-707826274b06.json  key unit-cell-atomic-system
# 7   51683d18-53ca-4458-a255-a89662a2b950.json  key unit-cell-atomic-system
# 8   8b349f7d-3991-438a-82d9-a54ea4aff2a2.json  key unit-cell-atomic-system
# 9   fc8071c6-c102-4c48-b208-6b5bfcb9b059.json  key unit-cell-atomic-system
# 10  7114d3f7-ca6a-4e62-a8ad-e0b4c38bad6b.json  key unit-cell-atomic-system
# 11  51683d18-53ca-4458-a255-a89662a2b950.json  key unit-cell-atomic-system
# 12  b795f6b7-e112-4955-8aef-707826274b06.json  key unit-cell-atomic-system
# 13  a0350c54-9efc-44c8-bba4-5785b8fcefe9.json  key unit-cell-atomic-system
# 14  235949ee-c95e-42d4-811e-97cd38ae26ba.json  key unit-cell-atomic-system
# 15  fc8071c6-c102-4c48-b208-6b5bfcb9b059.json  key unit-cell-atomic-system
# 16  51683d18-53ca-4458-a255-a89662a2b950.json  key unit-cell-atomic-system
# 17  2e05623b-4aa8-4fa4-9dde-23ea692a264e.json  key unit-cell-atomic-system
# 18  a68c0c58-20ce-467c-9ec2-1788fc8a8abc.json  key unit-cell-atomic-system
# 19  a68c0c58-20ce-467c-9ec2-1788fc8a8abc.json  key unit-cell-atomic-system
# 20  fc8071c6-c102-4c48-b208-6b5bfcb9b059.json  key unit-cell-atomic-system
# 21  8b349f7d-3991-438a-82d9-a54ea4aff2a2.json  key unit-cell-atomic-system
# 22  a6fc7ab6-69d5-4dab-bfab-6fb47026cf0f.json  key unit-cell-atomic-system
# 23  ef0dea21-0245-41a4-a924-ae589ce04f06.json  key unit-cell-atomic-system
# 24  c1ec7d94-51af-442e-a228-1344a6b4bd4d.json  key unit-cell-atomic-system
# 25  b74fd355-5ab6-4db6-b494-acfce3eb888e.json  key unit-cell-atomic-system
# 26  e28fe811-3c5f-48f8-afc9-bf4c5eab15ca.json  key unit-cell-atomic-system
# 27  e28fe811-3c5f-48f8-afc9-bf4c5eab15ca.json  key unit-cell-atomic-system
# 28  8b349f7d-3991-438a-82d9-a54ea4aff2a2.json  key unit-cell-atomic-system
# 29  235949ee-c95e-42d4-811e-97cd38ae26ba.json  key unit-cell-atomic-system
# 30  a68c0c58-20ce-467c-9ec2-1788fc8a8abc.json  key unit-cell-atomic-system
# 31  ef0dea21-0245-41a4-a924-ae589ce04f06.json  key unit-cell-atomic-system
# 33  c1ec7d94-51af-442e-a228-1344a6b4bd4d.json  key unit-cell-atomic-system
# 34  7114d3f7-ca6a-4e62-a8ad-e0b4c38bad6b.json  key unit-cell-atomic-system
# 35  a68c0c58-20ce-467c-9ec2-1788fc8a8abc.json  key unit-cell-atomic-system
# 36  7114d3f7-ca6a-4e62-a8ad-e0b4c38bad6b.json  key unit-cell-atomic-system
# 38  a0350c54-9efc-44c8-bba4-5785b8fcefe9.json  key unit-cell-atomic-system
# 39  ef0dea21-0245-41a4-a924-ae589ce04f06.json  key unit-cell-atomic-system
# 40  235949ee-c95e-42d4-811e-97cd38ae26ba.json  key unit-cell-atomic-system
# 41  a6fc7ab6-69d5-4dab-bfab-6fb47026cf0f.json  key unit-cell-atomic-system
# 42  e28fe811-3c5f-48f8-afc9-bf4c5eab15ca.json  key unit-cell-atomic-system
# 43  a0350c54-9efc-44c8-bba4-5785b8fcefe9.json  key unit-cell-atomic-system
# 44  b795f6b7-e112-4955-8aef-707826274b06.json  key unit-cell-atomic-system
# 45  b795f6b7-e112-4955-8aef-707826274b06.json  key unit-cell-atomic-system
# 46  a6fc7ab6-69d5-4dab-bfab-6fb47026cf0f.json  key unit-cell-atomic-system
# 48  fc8071c6-c102-4c48-b208-6b5bfcb9b059.json  key unit-cell-atomic-system
# 49  b74fd355-5ab6-4db6-b494-acfce3eb888e.json  key unit-cell-atomic-system
# 50  a6fc7ab6-69d5-4dab-bfab-6fb47026cf0f.json  key unit-cell-atomic-system
# 51  b74fd355-5ab6-4db6-b494-acfce3eb888e.json  key unit-cell-atomic-system
# 52  2e05623b-4aa8-4fa4-9dde-23ea692a264e.json  key unit-cell-atomic-system
# 53  2e05623b-4aa8-4fa4-9dde-23ea692a264e.json  key unit-cell-atomic-system
# 54  b74fd355-5ab6-4db6-b494-acfce3eb888e.json  key unit-cell-atomic-system
# 55  51683d18-53ca-4458-a255-a89662a2b950.json  key unit-cell-atomic-system
# 56  7114d3f7-ca6a-4e62-a8ad-e0b4c38bad6b.json  key unit-cell-atomic-system
# 57  c1ec7d94-51af-442e-a228-1344a6b4bd4d.json  key unit-cell-atomic-system
# 58  ef0dea21-0245-41a4-a924-ae589ce04f06.json  key unit-cell-atomic-system
# 59  a0350c54-9efc-44c8-bba4-5785b8fcefe9.json  key unit-cell-atomic-system
#
#       load_style                   potential_LAMMPS_id  \
# 0   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 1   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 2   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 3   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 5   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 6   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 7   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 8   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 9   system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 10  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 11  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 12  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 13  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 14  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 15  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 16  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 17  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 18  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 19  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 20  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 21  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 22  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 23  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 24  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 25  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 26  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 27  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 28  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 29  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 30  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 31  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 33  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 34  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 35  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 36  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 38  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 39  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 40  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 41  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 42  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 43  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 44  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 45  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 46  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 48  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 49  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 50  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 51  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 52  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 53  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 54  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 55  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 56  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 57  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 58  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
# 59  system_model  2006--Williams-P-L--Ag--LAMMPS--ipr1
#
#               ...                                     potential_key  \
# 0             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 1             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 2             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 3             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 5             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 6             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 7             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 8             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 9             ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 10            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 11            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 12            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 13            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 14            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 15            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 16            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 17            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 18            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 19            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 20            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 21            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 22            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 23            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 24            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 25            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 26            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 27            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 28            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 29            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 30            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 31            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 33            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 34            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 35            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 36            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 38            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 39            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 40            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 41            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 42            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 43            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 44            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 45            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 46            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 48            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 49            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 50            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 51            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 52            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 53            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 54            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 55            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 56            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 57            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 58            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
# 59            ...              ce32faaf-5d57-4861-a2ec-efbfc63f07e6
#
#                                      raw_cij_negative  \
# 0   [[0.9981299782567745, 0.519784983869613, 0.519...
# 1   [[0.7754400402332803, 0.5859135960201266, 0.58...
# 2   [[0.9155093880846337, 0.587837159089215, 0.468...
# 3   [[1.7188557949937802, 0.1166481994723816, 0.11...
# 5   [[1.2300206002192275, 0.3344978810216979, 0.33...
# 6   [[-771.562260178292, -531.5306901329793, -1878...
# 7   [[-0.8437595810493815, 2.6753583961808216, 0.2...
# 8   [[0.9155097856544541, 0.5878372246520955, 0.46...
# 9   [[0.8013066494517107, 0.5604848822200191, 0.56...
# 10  [[0.915895830063836, 0.5802079441302368, 0.458...
# 11  [[-0.3053060776599829, 2.1369902234466043, 0.2...
# 12  [[0.5680243561788716, 0.7991566324451891, 0.05...
# 13  [[0.5541181380356447, 0.414254688402109, 0.543...
# 14  [[1.7188413696569547, 0.11664781476058542, 0.1...
# 15  [[0.7683156068431635, 0.5749387404207539, 0.57...
# 8   [[0.9155090109215029, 0.5878369881563225, 0.46...
# 9   [[0.8014515146090654, 0.560538889497176, 0.560...
# 10  [[0.915817619979106, 0.5801817549754482, 0.458...
# 11  [[1.7159895362421276, 0.11569454321745591, 0.2...
# 12  [[0.5680241253522489, 0.7991568019583434, 0.05...
# 13  [[0.5540945675966413, 0.41427283658992264, 0.5...
# 14  [[1.718841083764027, 0.1166478070813868, 0.116...
# 15  [[0.7683265846139188, 0.5749506822841777, 0.57...
# 16  [[-0.820668468821806, 2.652360716643747, 0.247...
# 17  [[1.2299802402165265, 0.33448640921193673, 0.3...
# 18  [[0.294618801077456, 0.3550857686498439, 0.355...
# 19  [[0.2946201862633947, 0.3550788109142976, 0.35...
# 20  [[0.7674472327988741, 0.5756482953006415, 0.57...
# 21  [[0.9155054805346479, 0.5878359666598079, 0.46...
# 22  [[0.7644997658108155, 0.573148327294372, 0.573...
# 23  [[1.0086632987788136, 0.5224538781822726, 0.52...
# 24  [[0.7754384709613855, 0.5859117056514468, 0.58...
# 25  [[0.7698941055478185, 0.7560543700702665, 0.75...
# 26  [[0.9662430917344031, 0.53223532480018, 0.5322...
# 27  [[0.9672240680927945, 0.5330840268530108, 0.53...
# 28  [[0.915470216138349, 0.5878257157174648, 0.468...
# 29  [[1.7186957501828286, 0.11664393336623073, 0.1...
# 30  [[0.29461894038700415, 0.35508507582608934, 0....
# 31  [[0.9726473486514433, 0.5358575872720432, 0.53...
# 33  [[0.7754246214770507, 0.5858949873450319, 0.58...
# 34  [[0.9158528135939843, 0.5801935401132916, 0.45...
# 35  [[0.2946188161647582, 0.3550857030026608, 0.35...
# 36  [[0.9158566600355648, 0.5801948474589216, 0.45...
# 38  [[0.5540350666612126, 0.41436073120858924, 0.5...
# 39  [[0.972992255385661, 0.5362704527179261, 0.536...
# 40  [[1.7188397898031373, 0.11664777267725727, 0.1...
# 41  [[0.7644190213742282, 0.5731151353540083, 0.57...
# 42  [[0.9663558917429731, 0.5321860412432029, 0.53...
# 43  [[0.5533880093749888, 0.4152479661338748, 0.54...
# 44  [[7385.231312200553, 8153.499403852946, 19675....
# 45  [[57533.78987073452, 80117.11389005782, 147380...
# 46  [[0.771657008359931, 0.5668775781848389, 0.566...
# 48  [[0.767503319613499, 0.575649873559326, 0.5756...
# 49  [[0.7699535518812762, 0.756099406967647, 0.756...
# 50  [[0.765615978660884, 0.5727261803380916, 0.572...
# 51  [[0.7699481480507795, 0.7560953133173473, 0.75...
# 52  [[1.2300201562467132, 0.33449775310478647, 0.3...
# 53  [[1.2300165267184473, 0.33449672178378886, 0.3...
# 54  [[0.7699540965255752, 0.7560998192601289, 0.75...
# 55  [[-0.3053036908501558, 2.1369885236623496, 0.2...
# 56  [[0.9158563312177428, 0.5801947197018698, 0.45...
# 57  [[0.775439855436313, 0.5859133768513334, 0.585...
# 58  [[0.972707920415532, 0.5357505687675005, 0.535...
# 59  [[0.5540584955438312, 0.41425859515051455, 0.5...
#
#                            script                 sizemults    status  \
# 0   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 1   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 2   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 3   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 5   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 6   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 7   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 8   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 9   calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 10  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 11  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 12  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 13  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 14  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 15  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 16  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 17  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 18  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 19  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 20  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 21  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 22  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 23  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 24  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 25  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 26  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 27  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 28  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 29  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 30  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 31  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 33  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 34  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 35  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 36  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 38  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 39  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 40  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 41  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 42  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 43  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 44  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 45  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 46  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 48  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 49  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 50  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 51  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 52  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 53  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 54  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 55  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 56  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 57  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 58  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
# 59  calc_elastic_constants_static  [[0, 3], [0, 3], [0, 3]]  finished
#
#      strainrange symbols  composition                  prototype
# 0   1.000000e-08    [Ag]           Ag               oqmd-1214769
# 1   1.000000e-08    [Ag]           Ag                A1--Cu--fcc
# 2   1.000000e-08    [Ag]           Ag                A3--Mg--hcp
# 3   1.000000e-06    [Ag]           Ag           Ah--alpha-Po--sc
# 5   1.000000e-08    [Ag]           Ag                A15--beta-W
# 6   1.000000e-05    [Ag]           Ag               oqmd-1215927
# 7   1.000000e-05    [Ag]           Ag                A5--beta-Sn
# 8   1.000000e-07    [Ag]           Ag                A3--Mg--hcp
# 9   1.000000e-08    [Ag]           Ag               oqmd-1214858
# 10  1.000000e-05    [Ag]           Ag  A3'--alpha-La--double-hcp
# 11  1.000000e-08    [Ag]           Ag                A5--beta-Sn
# 12  1.000000e-08    [Ag]           Ag               oqmd-1215927
# 13  1.000000e-06    [Ag]           Ag               oqmd-1214680
# 14  1.000000e-08    [Ag]           Ag           Ah--alpha-Po--sc
# 15  1.000000e-07    [Ag]           Ag               oqmd-1214858
# 16  1.000000e-06    [Ag]           Ag                A5--beta-Sn
# 17  1.000000e-05    [Ag]           Ag                A15--beta-W
# 18  1.000000e-08    [Ag]           Ag                  A4--C--dc
# 19  1.000000e-05    [Ag]           Ag                  A4--C--dc
# 20  1.000000e-05    [Ag]           Ag               oqmd-1214858
# 21  1.000000e-06    [Ag]           Ag                A3--Mg--hcp
# 22  1.000000e-06    [Ag]           Ag               oqmd-1214858
# 23  1.000000e-08    [Ag]           Ag               oqmd-1214769
# 24  1.000000e-06    [Ag]           Ag                A1--Cu--fcc
# 25  1.000000e-05    [Ag]           Ag                 A2--W--bcc
# 26  1.000000e-05    [Ag]           Ag               oqmd-1214769
# 27  1.000000e-07    [Ag]           Ag               oqmd-1214769
# 28  1.000000e-05    [Ag]           Ag                A3--Mg--hcp
# 29  1.000000e-05    [Ag]           Ag           Ah--alpha-Po--sc
# 30  1.000000e-06    [Ag]           Ag                  A4--C--dc
# 31  1.000000e-05    [Ag]           Ag               oqmd-1214769
# 33  1.000000e-05    [Ag]           Ag                A1--Cu--fcc
# 34  1.000000e-06    [Ag]           Ag  A3'--alpha-La--double-hcp
# 35  1.000000e-07    [Ag]           Ag                  A4--C--dc
# 36  1.000000e-08    [Ag]           Ag  A3'--alpha-La--double-hcp
# 38  1.000000e-07    [Ag]           Ag               oqmd-1214680
# 39  1.000000e-07    [Ag]           Ag               oqmd-1214769
# 40  1.000000e-07    [Ag]           Ag           Ah--alpha-Po--sc
# 41  1.000000e-05    [Ag]           Ag               oqmd-1214858
# 42  1.000000e-06    [Ag]           Ag               oqmd-1214769
# 43  1.000000e-08    [Ag]           Ag               oqmd-1214680
# 44  1.000000e-06    [Ag]           Ag               oqmd-1215927
# 45  1.000000e-07    [Ag]           Ag               oqmd-1215927
# 46  1.000000e-08    [Ag]           Ag               oqmd-1214858
# 48  1.000000e-06    [Ag]           Ag               oqmd-1214858
# 49  1.000000e-07    [Ag]           Ag                 A2--W--bcc
# 50  1.000000e-07    [Ag]           Ag               oqmd-1214858
# 51  1.000000e-06    [Ag]           Ag                 A2--W--bcc
# 52  1.000000e-07    [Ag]           Ag                A15--beta-W
# 53  1.000000e-06    [Ag]           Ag                A15--beta-W
# 54  1.000000e-08    [Ag]           Ag                 A2--W--bcc
# 55  1.000000e-07    [Ag]           Ag                A5--beta-Sn
# 56  1.000000e-07    [Ag]           Ag  A3'--alpha-La--double-hcp
# 57  1.000000e-07    [Ag]           Ag                A1--Cu--fcc
# 58  1.000000e-06    [Ag]           Ag               oqmd-1214769
# 59  1.000000e-05    [Ag]           Ag               oqmd-1214680
#
# [56 rows x 22 columns]

# %%
data = []
for record in records.itertuples():
    crystal = unique_crystals[unique_crystals.calc_key == record.load_file.split('.')[0]].iloc[0]
    
    dat = {}
    dat['calc_key'] = record.key
    dat['potential_LAMMPS_key'] = crystal.potential_LAMMPS_key
    dat['potential_LAMMPS_id'] = crystal.potential_LAMMPS_id
    dat['potential_key'] = crystal.potential_key
    dat['potential_id'] = crystal.potential_id
    dat['prototype'] = crystal.prototype
    dat['family'] = crystal.family
    dat['composition'] = crystal.composition
    dat['strainrange'] = record.strainrange
    dat['a'] = crystal.a
    dat['b'] = crystal.b
    dat['c'] = crystal.c
    dat['alpha'] = crystal.alpha
    dat['beta'] = crystal.beta
    dat['gamma'] = crystal.gamma

    dat['straindirection'] = 'positive'
    cij = uc.get_in_units(record.raw_cij_positive, 'GPa')
    dat['C11'] = '%.3f' %cij[0,0]
    dat['C12'] = '%.3f' %cij[0,1]
    dat['C13'] = '%.3f' %cij[0,2]
    dat['C14'] = '%.3f' %cij[0,3]
    dat['C15'] = '%.3f' %cij[0,4]
    dat['C16'] = '%.3f' %cij[0,5]
    dat['C21'] = '%.3f' %cij[1,0]
    dat['C22'] = '%.3f' %cij[1,1]
    dat['C23'] = '%.3f' %cij[1,2]
    dat['C24'] = '%.3f' %cij[1,3]
    dat['C25'] = '%.3f' %cij[1,4]
    dat['C26'] = '%.3f' %cij[1,5]
    dat['C31'] = '%.3f' %cij[2,0]
    dat['C32'] = '%.3f' %cij[2,1]
    dat['C33'] = '%.3f' %cij[2,2]
    dat['C34'] = '%.3f' %cij[2,3]
    dat['C35'] = '%.3f' %cij[2,4]
    dat['C36'] = '%.3f' %cij[2,5]
    dat['C41'] = '%.3f' %cij[3,0]
    dat['C42'] = '%.3f' %cij[3,1]
    dat['C43'] = '%.3f' %cij[3,2]
    dat['C44'] = '%.3f' %cij[3,3]
    dat['C45'] = '%.3f' %cij[3,4]
    dat['C46'] = '%.3f' %cij[3,5]
    dat['C51'] = '%.3f' %cij[4,0]
    dat['C52'] = '%.3f' %cij[4,1]
    dat['C53'] = '%.3f' %cij[4,2]
    dat['C54'] = '%.3f' %cij[4,3]
    dat['C55'] = '%.3f' %cij[4,4]
    dat['C56'] = '%.3f' %cij[4,5]
    dat['C61'] = '%.3f' %cij[5,0]
    dat['C62'] = '%.3f' %cij[5,1]
    dat['C63'] = '%.3f' %cij[5,2]
    dat['C64'] = '%.3f' %cij[5,3]
    dat['C65'] = '%.3f' %cij[5,4]
    dat['C66'] = '%.3f' %cij[5,5]
    data.append(deepcopy(dat))

    dat['straindirection'] = 'negative'
    cij = uc.get_in_units(record.raw_cij_negative, 'GPa')
    dat['C11'] = '%.3f' %cij[0,0]
    dat['C12'] = '%.3f' %cij[0,1]
    dat['C13'] = '%.3f' %cij[0,2]
    dat['C14'] = '%.3f' %cij[0,3]
    dat['C15'] = '%.3f' %cij[0,4]
    dat['C16'] = '%.3f' %cij[0,5]
    dat['C21'] = '%.3f' %cij[1,0]
    dat['C22'] = '%.3f' %cij[1,1]
    dat['C23'] = '%.3f' %cij[1,2]
    dat['C24'] = '%.3f' %cij[1,3]
    dat['C25'] = '%.3f' %cij[1,4]
    dat['C26'] = '%.3f' %cij[1,5]
    dat['C31'] = '%.3f' %cij[2,0]
    dat['C32'] = '%.3f' %cij[2,1]
    dat['C33'] = '%.3f' %cij[2,2]
    dat['C34'] = '%.3f' %cij[2,3]
    dat['C35'] = '%.3f' %cij[2,4]
    dat['C36'] = '%.3f' %cij[2,5]
    dat['C41'] = '%.3f' %cij[3,0]
    dat['C42'] = '%.3f' %cij[3,1]
    dat['C43'] = '%.3f' %cij[3,2]
    dat['C44'] = '%.3f' %cij[3,3]
    dat['C45'] = '%.3f' %cij[3,4]
    dat['C46'] = '%.3f' %cij[3,5]
    dat['C51'] = '%.3f' %cij[4,0]
    dat['C52'] = '%.3f' %cij[4,1]
    dat['C53'] = '%.3f' %cij[4,2]
    dat['C54'] = '%.3f' %cij[4,3]
    dat['C55'] = '%.3f' %cij[4,4]
    dat['C56'] = '%.3f' %cij[4,5]
    dat['C61'] = '%.3f' %cij[5,0]
    dat['C62'] = '%.3f' %cij[5,1]
    dat['C63'] = '%.3f' %cij[5,2]
    dat['C64'] = '%.3f' %cij[5,3]
    dat['C65'] = '%.3f' %cij[5,4]
    dat['C66'] = '%.3f' %cij[5,5]
    data.append(deepcopy(dat))

columns = ['calc_key', 'potential_LAMMPS_key', 'potential_LAMMPS_id', 'potential_key', 'potential_id',
           'composition', 'prototype', 'family', 
           'a', 'b', 'c', 'alpha', 'beta', 'gamma',
           'strainrange', 'straindirection', 
           'C11', 'C12', 'C13', 'C14', 'C15', 'C16',
           'C21', 'C22', 'C23', 'C24', 'C25', 'C26',
           'C31', 'C32', 'C33', 'C34', 'C35', 'C36',
           'C41', 'C42', 'C43', 'C44', 'C45', 'C46',
           'C51', 'C52', 'C53', 'C54', 'C55', 'C56',
           'C61', 'C62', 'C63', 'C64', 'C65', 'C66']

data = pd.DataFrame(data, columns=columns).sort_values(['potential_LAMMPS_id', 'composition', 'prototype', 'strainrange', 'straindirection'])

# %%
data.to_csv('elastic-constants.csv')

# %%
for i in range(6):
    for j in range(6):
        print(i, j, record.raw_cij_positive[i,j] - record.raw_cij_positive[j,i])
# Out:
# 0 0 0.0
# 0 1 0.014007833025681315
# 0 2 1.213081024520335e-05
# 0 3 -9.267338712355426e-06
# 0 4 3.664908123963368e-05
# 0 5 -1.0116550891086139e-05
# 1 0 -0.014007833025681315
# 1 1 0.0
# 1 2 -0.013995781938079488
# 1 3 -5.917426740206227e-06
# 1 4 -1.3989912938078078e-06
# 1 5 -7.328756466577149e-06
# 2 0 -1.213081024520335e-05
# 2 1 0.013995781938079488
# 2 2 0.0
# 2 3 -9.347732214957515e-06
# 2 4 4.426728055781595e-05
# 2 5 -1.3428046564262807e-05
# 3 0 9.267338712355426e-06
# 3 1 5.917426740206227e-06
# 3 2 9.347732214957515e-06
# 3 3 0.0
# 3 4 1.3617138553361802e-11
# 3 5 7.857531994214562e-11
# 4 0 -3.664908123963368e-05
# 4 1 1.3989912938078078e-06
# 4 2 -4.426728055781595e-05
# 4 3 -1.3617138553361802e-11
# 4 4 0.0
# 4 5 -1.78485620492013e-12
# 5 0 1.0116550891086139e-05
# 5 1 7.328756466577149e-06
# 5 2 1.3428046564262807e-05
# 5 3 -7.857531994214562e-11
# 5 4 1.78485620492013e-12
# 5 5 0.0

# %% [markdown]
# ### Add info to PotentialProperties records
#
# This is for generating XML records that the Interatomic Potential Repository uses to automatically build webcontent (done elsewhere).

# %%
# Add calculation data to PotentialProperties records
for implememtation_key in np.unique(records.potential_LAMMPS_key):
    imp_records = records[records.potential_LAMMPS_key == implememtation_key].sort_values('family')
    pot_record = pot_records[pot_records.key == implememtation_key].iloc[0]
    implementation_id = pot_record.id
    potential_id = pot_record.pot_id
    potential_key = pot_record.pot_key
    
    record_name = 'properties.' + implementation_id
    try:
        record = database.get_record(name=record_name, style='PotentialProperties')
    except:
        new = True
        content = DM()
        content['per-potential-properties'] = DM()
        content['per-potential-properties']['potential'] = DM()
        content['per-potential-properties']['potential']['key'] = potential_key
        content['per-potential-properties']['potential']['id'] = potential_id
        content['per-potential-properties']['implementation'] = DM()
        content['per-potential-properties']['implementation']['key'] = implememtation_key
        content['per-potential-properties']['implementation']['id'] = implementation_id
    else:
        content = DM(record.content)
        new = False
    
    content['per-potential-properties']['elastic-constants'] = DM()
    for composition in np.unique(imp_records.composition):
        content['per-potential-properties']['cohesive-energy-scan'].append('composition', composition)
    
    if new:
        database.add_record(name=record_name, style='PotentialProperties', content=content.xml())
    else:
        database.update_record(record=record, content=content.xml())
