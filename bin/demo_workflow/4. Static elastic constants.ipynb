# %% [markdown]
# # Static elastic constants
# This Notebook follows the workflow for setting up, running, and processing the elastic_constants_static calculations.
#
# **Quick Notes:**
#
# - All input scripts take key-value pairs where the "key"s correspond to the calculation's input parameters.
#
# - Multiple calculations are prepared by specifying multiple values for the same key (on separate lines).
#
# - The special "buildcombos" key accesses predefined functions for generating lists of input parameter values for certain sets of keys.  See documentation for more details.

# %% [markdown]
# __Global workflow details:__
#
# This Notebook requires calculation_crystal_space_group records and the "unique_crystals.csv" file, both of which are generated by the "3. Crystal relaxation" Notebook.
#
# The calculation_elastic_constants_static records generated are used as inputs for dislocation creation Notebooks.

# %% [markdown]
# **Library imports**

# %%
# Standard Python libraries
from __future__ import (absolute_import, print_function,
                        division, unicode_literals)
import os
from datetime import date
from math import floor
from copy import deepcopy

# http://www.numpy.org/
import numpy as np

# https://pandas.pydata.org/
import pandas as pd

# https://bokeh.pydata.org/
import bokeh
import bokeh.plotting
import bokeh.resources
import bokeh.io
import bokeh.models

from DataModelDict import DataModelDict as DM

# https://github.com/usnistgov/atomman
import atomman.unitconvert as uc

# https://github.com/usnistgov/iprPy
import iprPy
print('iprPy version', iprPy.__version__)
# Out:
# iprPy version 0.8.3

# %% [markdown]
# ## 0. Access database

# %% [markdown]
# ### Load database

# %%
database = iprPy.load_database('demo')

# %% [markdown]
# ### Load unique crystals

# %%
unique_crystals = pd.read_csv('unique_crystals.csv')
print(len(unique_crystals))
# Out:
# 104

# %% [markdown]
# ### Limit unique crystals to include (optional)

# %%
#unique_crystals = unique_crystals[unique_crystals.potential_LAMMPS_id == '2012--Park-H--Mo--LAMMPS--ipr1']
#unique_crystals = unique_crystals[unique_crystals.composition == '']
#unique_crystals = unique_crystals[unique_crystals.prototype == '']
print(len(unique_crystals))
# Out:
# 104

# %% [markdown]
# ## 1. Run elastic_constants_static calculations
#
# This calculation evaluates the elastic constants for a crystal using small strain deformations.

# %%
calculation = iprPy.load_calculation('elastic_constants_static')
run_directory = iprPy.load_run_directory('demo_1')

# %% [markdown]
# ### Show calculation's allowed keys
#
# These are the keys that the input script will accept.

# %%
print(calculation.allkeys)
# Out:
# ['lammps_command', 'mpi_command', 'length_unit', 'pressure_unit', 'energy_unit', 'force_unit', 'potential_file', 'potential_content', 'potential_dir', 'load_file', 'load_content', 'load_style', 'family', 'load_options', 'symbols', 'box_parameters', 'a_uvw', 'b_uvw', 'c_uvw', 'atomshift', 'sizemults', 'strainrange', 'energytolerance', 'forcetolerance', 'maxiterations', 'maxevaluations', 'maxatommotion']

# %% [markdown]
# ### Write input script

# %%
input_script = """
# Commands and executables
lammps_command              lmp_mpi
mpi_command                 

# Build load information from crystal_space_group results
buildcombos                 atomicparent load_file parent
parent_record               calculation_crystal_space_group
parent_load_key             unit-cell-atomic-system

# System manipulations
a_uvw                      
b_uvw                      
c_uvw                 
atomshift                   
sizemults                   5 5 5

# Units that input/output values are in
length_unit                 
pressure_unit               
energy_unit                 
force_unit                  

# Run parameters
energytolerance             
forcetolerance              
maxiterations               
maxevaluations              
maxatommotion               
strainrange                  1e-5
strainrange                  1e-6
strainrange                  1e-7
strainrange                  1e-8
"""

with open('input_script.in', 'w') as f:
    f.write(input_script)

# %% [markdown]
# ### Parse input script

# %%
with open('input_script.in') as f:
    input_dict = iprPy.input.parse(f, singularkeys=calculation.singularkeys)

# %% [markdown]
# ### Add parent_name list using unique crystals

# %%
input_dict['parent_name'] = unique_crystals.calc_key.tolist()

# %% [markdown]
# ### Prepare calculations

# %%
database.prepare(run_directory, calculation, **input_dict)

# %%
database.check_records(calculation.record_style)
# Out:
# In database style local at C:\Users\lmh1\Documents\calculations\ipr\demo :
# - 416 of style calculation_elastic_constants_static
#  - 0 are complete
#  - 416 still to run
#  - 0 issued errors

# %% [markdown]
# ### Run calculations

# %%
database.runner(run_directory)
# Out:
# Runner started with pid 13716
# No simulations left to run

# %%
results_df = database.get_records_df(style=calculation.record_style)
error_df = results_df[results_df.status=='error']
print(len(error_df), 'calculations issued errors:')
errors = []
for error in error_df.error:
    lines = error.splitlines()
    err = ''
    for i in range(len(lines)-1, -1, -1):
        if 'Error:' in lines[i]:
            err = '\n'.join(lines[i:-1])
            break
        if i == 0:
            err = error
    errors.append(err)
for error in np.unique(errors):
    print(error)
# Out:
# 6 calculations issued errors:
# AssertionError: Cij values not valid
# ValueError: Invalid LAMMPS input:
# Last command: read_restart initial.restart

# %% [markdown]
# ## 2. Calculation analysis

# %% [markdown]
# ### Retrieve finished calculation results

# %%
records = database.get_records_df(style='calculation_elastic_constants_static', full=True, flat=False, status='finished')
pot_records = database.get_records_df(style='potential_LAMMPS')

# %% [markdown]
# ### Identify compositions

# %%
iprPy.analysis.assign_composition(records, database)

# %%
# Settings
outputpath = 'C:/Users/lmh1/Documents/demo_results'
#savecolumns = ['calc_key', 'composition', 'prototype', 'family', 'a', 
#               'strainrange', '', 'gamma_fs']

# %% [markdown]
# ### Save raw data

# %%
records
# Out:
#                                                      C    LAMMPS_version  \
# 0    [[ 2.01919471 -0.01142724  0.40949518  0.     ...       22 Aug 2018
# 1    [[ 2.77109939e+00  1.05794816e+00  1.24983931e...       22 Aug 2018
# 2    [[0.30255725 0.22901108 0.36334093 0.         ...  26 Jan 2017-ICMS
# 3    [[ 6.46155092e-01  6.53178728e-01  6.53178727e...  26 Jan 2017-ICMS
# 4    [[ 4.66734740e-01  4.72271563e-01  3.76785109e...       22 Aug 2018
# 5    [[0.83104393 0.88640811 0.85295701 0.         ...       22 Aug 2018
# 6    [[-0.47048672 -0.10663233  0.49588942 -0.35094...       22 Aug 2018
# 7    [[ 1.72815626  0.11631619  0.11631619  0.     ...       22 Aug 2018
# 8    [[ 1.28868162e+00  7.59421924e-01  5.48209158e...       22 Aug 2018
# 9    [[ 1.85913508e+00  9.43637468e-01  5.81983049e...  26 Jan 2017-ICMS
# 10   [[ 5.63874518e-01  4.02523421e-02 -8.05570261e...       22 Aug 2018
# 11   [[ 1.72815624  0.11631619  0.11631618  0.     ...  26 Jan 2017-ICMS
# 12   [[ 2.00981081e+00  6.11103181e-01  6.11103184e...       22 Aug 2018
# 13   [[1.09801497 0.6966171  0.6966171  0.         ...       22 Aug 2018
# 406  [[ 1.48921595  0.14923022  0.72727107  0.     ...  26 Jan 2017-ICMS
# 407  [[2.38529196 0.40665148 0.40665148 0.         ...       22 Aug 2018
# 408  [[0.85155201 0.31940781 0.17402138 0.         ...  26 Jan 2017-ICMS
# 409  [[ 1.01724904e+00  8.49620763e-01  8.02416265e...       22 Aug 2018
# 410  [[-3.70626656e+02 -6.82051899e+01 -1.12903516e...       22 Aug 2018
# 411  [[1.52685238 0.81764266 0.47099486 0.         ...       22 Aug 2018
# 412  [[1.54425464 0.73616415 0.47278733 0.         ...       22 Aug 2018
# 413  [[-9.72476443e+04  6.13155791e+01  6.19667933e...  26 Jan 2017-ICMS
# 414  [[1.74957393 0.38795414 0.38795414 0.         ...       22 Aug 2018
# 415  [[ 2.39800637  0.64373081  0.64373081  0.     ...       22 Aug 2018
#
#     error                      family iprPy_version  \
# 0     NaN                oqmd-1214728         0.8.3
# 1     NaN                oqmd-1220003         0.8.3
# 2     NaN   A3'--alpha-La--double-hcp         0.8.3
# 3     NaN                  D0_3--BiF3         0.8.3
# 4     NaN                oqmd-1215683         0.8.3
# 5     NaN                  mp-1010136         0.8.3
# 6     NaN                A7--alpha-As         0.8.3
# 7     NaN            Ah--alpha-Po--sc         0.8.3
# 8     NaN   A3'--alpha-La--double-hcp         0.8.3
# 9     NaN   A3'--alpha-La--double-hcp         0.8.3
# 10    NaN                  mp-1094136         0.8.3
# 11    NaN            Ah--alpha-Po--sc         0.8.3
# 12    NaN                oqmd-1214817         0.8.3
# 13    NaN                oqmd-1214876         0.8.3
# 14    NaN                 oqmd-338617         0.8.3
# 15    NaN                oqmd-1214906         0.8.3
# 16    NaN                  A15--Cr3Si         0.8.3
# 17    NaN                oqmd-1232654         0.8.3
# 18    NaN                oqmd-1215975         0.8.3
# 19    NaN                A7--alpha-As         0.8.3
# 20    NaN                oqmd-1232654         0.8.3
# 21    NaN                  mp-1225694         0.8.3
# 22    NaN                oqmd-1215619         0.8.3
# 23    NaN                 L1_2--AuCu3         0.8.3
# 24    NaN                 oqmd-345531         0.8.3
# 25    NaN                oqmd-1214817         0.8.3
# 26    NaN                 A5--beta-Sn         0.8.3
# 27    NaN                  mp-1094136         0.8.3
# 28    NaN                 A1--Cu--fcc         0.8.3
# 29    NaN                oqmd-1214817         0.8.3
# ..    ...                         ...           ...
# 385   NaN                 oqmd-302756         0.8.3
# 386   NaN            Ah--alpha-Po--sc         0.8.3
# 388   NaN            Ah--alpha-Po--sc         0.8.3
# 389   NaN                 oqmd-299961         0.8.3
# 390   NaN                  A15--Cr3Si         0.8.3
# 391   NaN                A7--alpha-As         0.8.3
# 392   NaN                  mp-1225694         0.8.3
# 393   NaN                 oqmd-299961         0.8.3
# 394   NaN                  mp-1184069         0.8.3
# 395   NaN  B3--ZnS--cubic-zinc-blende         0.8.3
# 396   NaN                oqmd-1215886         0.8.3
# 397   NaN                  D0_3--BiF3         0.8.3
# 398   NaN                  A15--Cr3Si         0.8.3
# 399   NaN                oqmd-1214876         0.8.3
# 400   NaN            Ah--alpha-Po--sc         0.8.3
# 401   NaN                 A15--beta-W         0.8.3
# 395  f278ba44-d71f-42cd-8d9e-2921a48b8fc0
# 396  f4de70ae-4982-4a31-b6fd-0c42482f4ca3
# 397  f552de0b-be64-499f-9eba-719ced38915f
# 398  f6eab44c-8235-4a93-bc12-7f6a074565ba
# 399  f7c72339-b405-400f-8f2c-a51809e6a606
# 400  f7d6e1e3-3e15-4b03-9ac2-7a79830db51f
# 401  f8027320-bda7-4b76-b7e8-ace345d3411b
# 402  f8048dca-5d61-4b1b-9cf2-d49c3d99b7e7
# 403  f80739fd-c737-47d5-87f6-335a30f48a58
# 404  f88ae058-b468-4b9c-8c8a-8bc54437507a
# 405  f96e7cc8-2a0f-440e-8b21-9c3823dd8a27
# 406  f9aff100-7ee1-4de6-9505-72e99e48fa3f
# 407  fb3a2f8c-14a8-4b21-9fe4-99f177dacf42
# 408  fc7b2ae6-3da7-406f-9c19-574ab0317c59
# 409  fcf8359b-546b-4ce1-9c7d-27d49686cdfd
# 410  fd41ab90-f9f6-4d99-b87e-067a2e399832
# 411  fd73086f-bfd2-4d8e-8a45-56d7e7a78176
# 412  fde22cad-ec67-4fde-9aeb-fe6e99705954
# 413  fed178eb-9ee4-4ba0-ae3f-4b0aeb664b71
# 414  ff0eba91-6b43-4e9f-9d15-a343dc60126f
# 415  ff5067de-9249-4c8e-9688-6d599337b745
#
#                                      load_file                 load_options  \
# 0    b7937265-1019-453a-a29a-f92ba7d19960.json  key unit-cell-atomic-system
# 1    a2bfffbd-606e-4903-b81b-d15a4016e2e0.json  key unit-cell-atomic-system
# 2    475b69d4-6fc9-4b37-bcc7-50155b565579.json  key unit-cell-atomic-system
# 3    dd2a5d41-9e9d-4788-88ea-472676de8229.json  key unit-cell-atomic-system
# 4    f5ebaa16-068a-43d1-8910-51df466d4203.json  key unit-cell-atomic-system
# 5    76fe0d14-43ef-4061-bb91-b150bed4579b.json  key unit-cell-atomic-system
# 6    9e03d38d-d121-4a04-96b3-3d340d330cce.json  key unit-cell-atomic-system
# 7    cf1926b8-9d1e-4275-8e07-23f82d4380c2.json  key unit-cell-atomic-system
# 8    b1eadd20-5363-4309-a06b-c260947644a6.json  key unit-cell-atomic-system
# 9    28e33b1c-d6ec-4438-8a00-ba5526f43a97.json  key unit-cell-atomic-system
# 10   8c6551c4-8926-42ad-be3c-1ac12098a4ee.json  key unit-cell-atomic-system
# 11   cf1926b8-9d1e-4275-8e07-23f82d4380c2.json  key unit-cell-atomic-system
# 12   739ad826-9a3b-46cc-8503-e52ffa9be45f.json  key unit-cell-atomic-system
# 13   9d1bca76-8049-4457-b238-b8f9063b52ad.json  key unit-cell-atomic-system
# 14   c7ba438b-df5c-4b37-bf18-54f0cf506c89.json  key unit-cell-atomic-system
# 15   69c1fe1c-2b29-465b-b182-b96156d8bab3.json  key unit-cell-atomic-system
# 16   b267c627-f922-4a71-92a1-075c522126c1.json  key unit-cell-atomic-system
# 17   bcb36109-3a59-44c6-a734-91f16921bd49.json  key unit-cell-atomic-system
# 18   89ca4c5b-c326-4be2-91a3-87a5e17fe77e.json  key unit-cell-atomic-system
# 19   bf358a87-9e4b-4d6e-9341-2b47cb94f3f7.json  key unit-cell-atomic-system
# 20   d6c98663-399d-49e5-87d6-48ffd2c1f2b0.json  key unit-cell-atomic-system
# 21   fcff920b-8ef6-4dbc-b4e7-f72299104a60.json  key unit-cell-atomic-system
# 22   c8b6f30a-685a-4eab-9e6f-edf8f75b47b8.json  key unit-cell-atomic-system
# 23   25992858-db1c-49e9-b717-34a3b5f539fb.json  key unit-cell-atomic-system
# 24   92f949aa-4ef9-4af0-8d78-b2b9a819e28b.json  key unit-cell-atomic-system
# 25   739ad826-9a3b-46cc-8503-e52ffa9be45f.json  key unit-cell-atomic-system
# 26   a1dc4968-c7c6-462a-b9c5-e5e043c80c62.json  key unit-cell-atomic-system
# 27   7c03dd2e-4ec0-4afb-abc4-14b7033a9c55.json  key unit-cell-atomic-system
# 28   5028ecce-272a-4a11-a3e4-10f97993fb8e.json  key unit-cell-atomic-system
# 29   739ad826-9a3b-46cc-8503-e52ffa9be45f.json  key unit-cell-atomic-system
# ..                                         ...                          ...
# 385  1809f306-2d8c-4148-bbfa-f8c876ca9913.json  key unit-cell-atomic-system
# 386  b462c0d0-f407-43fd-9565-f79740019058.json  key unit-cell-atomic-system
# 388  b462c0d0-f407-43fd-9565-f79740019058.json  key unit-cell-atomic-system
# 389  9b395484-08f4-45e9-b48f-3be0449f3c99.json  key unit-cell-atomic-system
# 390  b267c627-f922-4a71-92a1-075c522126c1.json  key unit-cell-atomic-system
# 391  9e03d38d-d121-4a04-96b3-3d340d330cce.json  key unit-cell-atomic-system
# 392  fcff920b-8ef6-4dbc-b4e7-f72299104a60.json  key unit-cell-atomic-system
# 393  9b395484-08f4-45e9-b48f-3be0449f3c99.json  key unit-cell-atomic-system
# 394  c1db91ce-6df5-433a-a557-b6baffd07f16.json  key unit-cell-atomic-system
# 395  99fe910e-5b46-463c-b10e-0058e982a825.json  key unit-cell-atomic-system
# 396  73945444-86be-479c-a9f6-73d33b338631.json  key unit-cell-atomic-system
# 397  dd2a5d41-9e9d-4788-88ea-472676de8229.json  key unit-cell-atomic-system
# 398  2b8f77ce-f662-4787-b920-1be9078c1885.json  key unit-cell-atomic-system
# 399  13c35bda-6014-4546-acd4-fb5fbef0aea3.json  key unit-cell-atomic-system
# 400  cf1926b8-9d1e-4275-8e07-23f82d4380c2.json  key unit-cell-atomic-system
# 401  23452184-1bb6-49ab-bc02-4729d82b57bb.json  key unit-cell-atomic-system
# 402  3fe58722-8e95-4489-860e-e8ac58261306.json  key unit-cell-atomic-system
# 403  b1eadd20-5363-4309-a06b-c260947644a6.json  key unit-cell-atomic-system
# 404  3fe58722-8e95-4489-860e-e8ac58261306.json  key unit-cell-atomic-system
# 405  7740a034-0e8b-4326-9720-daec55805de8.json  key unit-cell-atomic-system
# 406  659c20e4-08c5-4146-aa0c-d3613c789543.json  key unit-cell-atomic-system
# 407  23452184-1bb6-49ab-bc02-4729d82b57bb.json  key unit-cell-atomic-system
# 408  ef3fa70d-36dd-437a-8eb0-f26f167e8ab7.json  key unit-cell-atomic-system
# 409  c226c1d1-5855-4c2b-aa6e-89a123a981b2.json  key unit-cell-atomic-system
# 410  d6c98663-399d-49e5-87d6-48ffd2c1f2b0.json  key unit-cell-atomic-system
# 411  c1db91ce-6df5-433a-a557-b6baffd07f16.json  key unit-cell-atomic-system
# 412  ea252eff-a5a6-46a9-b874-f56373748397.json  key unit-cell-atomic-system
# 413  7b123811-118a-4d7b-9ec7-5d00b4bd0849.json  key unit-cell-atomic-system
# 414  3d54a500-56d1-474f-ac5a-779dd6c1049d.json  key unit-cell-atomic-system
# 415  88b1ba7c-16d0-4f3c-8022-254248f3e121.json  key unit-cell-atomic-system
#
#        load_style                     potential_LAMMPS_id     ...      \
# 0    system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 1    system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 2    system_model  2003--Mendelev-M-I--Fe-2--LAMMPS--ipr3     ...
# 3    system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 4    system_model  2003--Mendelev-M-I--Fe-2--LAMMPS--ipr3     ...
# 5    system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 6    system_model  2003--Mendelev-M-I--Fe-2--LAMMPS--ipr3     ...
# 7    system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 8    system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 9    system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 10   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 11   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 12   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 13   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 14   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 15   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 16   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 17   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 18   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 19   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 20   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 21   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 22   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 23   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 24   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 25   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 26   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 27   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 28   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 29   system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# ..            ...                                     ...     ...
# 385  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 386  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 388  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 389  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 390  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 391  system_model  2003--Mendelev-M-I--Fe-2--LAMMPS--ipr3     ...
# 392  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 393  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 394  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 395  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 396  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 397  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 398  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 399  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 400  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 401  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 402  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 403  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 404  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 405  system_model  2003--Mendelev-M-I--Fe-2--LAMMPS--ipr3     ...
# 406  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 407  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 408  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 409  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 410  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 411  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 412  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 413  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
# 414  system_model  2003--Mendelev-M-I--Fe-2--LAMMPS--ipr3     ...
# 415  system_model   1985--Foiles-S-M--Ni-Cu--LAMMPS--ipr1     ...
#
#                                           potential_id  \
# 0                              1985--Foiles-S-M--Ni-Cu
# 1                              1985--Foiles-S-M--Ni-Cu
# 2    2003--Mendelev-M-I-Han-S-Srolovitz-D-J-et-al--...
# 3                              1985--Foiles-S-M--Ni-Cu
# 4    2003--Mendelev-M-I-Han-S-Srolovitz-D-J-et-al--...
# 5                              1985--Foiles-S-M--Ni-Cu
# 6    2003--Mendelev-M-I-Han-S-Srolovitz-D-J-et-al--...
# 7                              1985--Foiles-S-M--Ni-Cu
# 8                              1985--Foiles-S-M--Ni-Cu
# 9                              1985--Foiles-S-M--Ni-Cu
# 10                             1985--Foiles-S-M--Ni-Cu
# 11                             1985--Foiles-S-M--Ni-Cu
# 12                             1985--Foiles-S-M--Ni-Cu
# 13                             1985--Foiles-S-M--Ni-Cu
# 14                             1985--Foiles-S-M--Ni-Cu
# 15                             1985--Foiles-S-M--Ni-Cu
# 16                             1985--Foiles-S-M--Ni-Cu
# 17                             1985--Foiles-S-M--Ni-Cu
# 18                             1985--Foiles-S-M--Ni-Cu
# 19                             1985--Foiles-S-M--Ni-Cu
# 20                             1985--Foiles-S-M--Ni-Cu
# 21                             1985--Foiles-S-M--Ni-Cu
# 22                             1985--Foiles-S-M--Ni-Cu
# 23                             1985--Foiles-S-M--Ni-Cu
# 24                             1985--Foiles-S-M--Ni-Cu
# 25                             1985--Foiles-S-M--Ni-Cu
# 26                             1985--Foiles-S-M--Ni-Cu
# 27                             1985--Foiles-S-M--Ni-Cu
# 28                             1985--Foiles-S-M--Ni-Cu
# 29                             1985--Foiles-S-M--Ni-Cu
# ..                                                 ...
# 385                            1985--Foiles-S-M--Ni-Cu
calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 13   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 14   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 15   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 16   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 17   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 18   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 19   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 20   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 21   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 22   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 23   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 24   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 25   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 26   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 27   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 28   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 29   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# ..                             ...                       ...       ...
# 385  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 386  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 388  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 389  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 390  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 391  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 392  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 393  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 394  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 395  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 396  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 397  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 398  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 399  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 400  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 401  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 402  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 403  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 404  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 405  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 406  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 407  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 408  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 409  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 410  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 411  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 412  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 413  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 414  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 415  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
#
#       strainrange   symbols composition
# 0    1.000000e-05      [Ni]          Ni
# 1    1.000000e-08  [Cu, Ni]        CuNi
# 2    1.000000e-07      [Fe]          Fe
# 3    1.000000e-07  [Cu, Ni]       CuNi3
# 4    1.000000e-08      [Fe]          Fe
# 5    1.000000e-05      [Cu]          Cu
# 6    1.000000e-07      [Fe]          Fe
# 7    1.000000e-07      [Cu]          Cu
# 8    1.000000e-08      [Cu]          Cu
# 9    1.000000e-08      [Ni]          Ni
# 10   1.000000e-06      [Ni]          Ni
# 11   1.000000e-08      [Cu]          Cu
# 12   1.000000e-08      [Ni]          Ni
# 13   1.000000e-06      [Cu]          Cu
# 14   1.000000e-05  [Cu, Ni]        CuNi
# 15   1.000000e-05      [Ni]          Ni
# 16   1.000000e-07  [Ni, Cu]       Cu3Ni
# 17   1.000000e-06  [Cu, Ni]       Cu2Ni
# 18   1.000000e-07      [Ni]          Ni
# 19   1.000000e-06      [Ni]          Ni
# 20   1.000000e-08  [Cu, Ni]       Cu2Ni
# 21   1.000000e-06  [Cu, Ni]       CuNi3
# 22   1.000000e-07      [Ni]          Ni
# 23   1.000000e-07  [Ni, Cu]       Cu3Ni
# 24   1.000000e-06  [Cu, Ni]       Cu3Ni
# 25   1.000000e-07      [Ni]          Ni
# 26   1.000000e-06      [Cu]          Cu
# 27   1.000000e-07      [Ni]          Ni
# 28   1.000000e-07      [Cu]          Cu
# 29   1.000000e-05      [Ni]          Ni
# ..            ...       ...         ...
# 385  1.000000e-06  [Cu, Ni]       Cu3Ni
# 386  1.000000e-08      [Ni]          Ni
# 388  1.000000e-05      [Ni]          Ni
# 389  1.000000e-05  [Cu, Ni]       CuNi3
# 390  1.000000e-08  [Ni, Cu]       Cu3Ni
# 391  1.000000e-08      [Fe]          Fe
# 392  1.000000e-08  [Cu, Ni]       CuNi3
# 393  1.000000e-07  [Cu, Ni]       CuNi3
# 394  1.000000e-08  [Cu, Ni]        CuNi
# 395  1.000000e-08  [Cu, Ni]        CuNi
# 396  1.000000e-08      [Ni]          Ni
# 397  1.000000e-06  [Cu, Ni]       CuNi3
# 398  1.000000e-05  [Cu, Ni]       CuNi3
# 399  1.000000e-08      [Cu]          Cu
# 400  1.000000e-05      [Cu]          Cu
# 401  1.000000e-05      [Ni]          Ni
# 402  1.000000e-07      [Ni]          Ni
# 403  1.000000e-06      [Cu]          Cu
# 404  1.000000e-06      [Ni]          Ni
# 405  1.000000e-08      [Fe]          Fe
# 406  1.000000e-06      [Cu]          Cu
# 407  1.000000e-07      [Ni]          Ni
# 408  1.000000e-05  [Cu, Ni]       CuNi3
# 409  1.000000e-08  [Cu, Ni]       Cu3Ni
# 410  1.000000e-05  [Cu, Ni]       Cu2Ni
# 411  1.000000e-05  [Cu, Ni]        CuNi
# 412  1.000000e-07  [Cu, Ni]       CuNi3
# 413  1.000000e-08      [Cu]          Cu
# 414  1.000000e-07      [Fe]          Fe
# 415  1.000000e-06  [Cu, Ni]       CuNi3
#
# [410 rows x 21 columns]

# %%
data = []
for record in records.itertuples():
    crystal = unique_crystals[unique_crystals.calc_key == record.load_file.split('.')[0]].iloc[0]
    
    dat = {}
    dat['calc_key'] = record.key
    dat['potential_LAMMPS_key'] = crystal.potential_LAMMPS_key
    dat['potential_LAMMPS_id'] = crystal.potential_LAMMPS_id
    dat['potential_key'] = crystal.potential_key
    dat['potential_id'] = crystal.potential_id
    dat['prototype'] = crystal.prototype
    dat['family'] = crystal.family
    dat['composition'] = record.composition
    dat['strainrange'] = record.strainrange
    dat['a'] = crystal.a
    dat['b'] = crystal.b
    dat['c'] = crystal.c
    dat['alpha'] = crystal.alpha
    dat['beta'] = crystal.beta
    dat['gamma'] = crystal.gamma

    dat['straindirection'] = 'positive'
    cij = uc.get_in_units(record.raw_cij_positive, 'GPa')
    dat['C11'] = '%.3f' %cij[0,0]
    dat['C12'] = '%.3f' %cij[0,1]
    dat['C13'] = '%.3f' %cij[0,2]
    dat['C14'] = '%.3f' %cij[0,3]
    dat['C15'] = '%.3f' %cij[0,4]
    dat['C16'] = '%.3f' %cij[0,5]
    dat['C21'] = '%.3f' %cij[1,0]
    dat['C22'] = '%.3f' %cij[1,1]
    dat['C23'] = '%.3f' %cij[1,2]
    dat['C24'] = '%.3f' %cij[1,3]
    dat['C25'] = '%.3f' %cij[1,4]
    dat['C26'] = '%.3f' %cij[1,5]
    dat['C31'] = '%.3f' %cij[2,0]
    dat['C32'] = '%.3f' %cij[2,1]
    dat['C33'] = '%.3f' %cij[2,2]
    dat['C34'] = '%.3f' %cij[2,3]
    dat['C35'] = '%.3f' %cij[2,4]
    dat['C36'] = '%.3f' %cij[2,5]
    dat['C41'] = '%.3f' %cij[3,0]
    dat['C42'] = '%.3f' %cij[3,1]
    dat['C43'] = '%.3f' %cij[3,2]
    dat['C44'] = '%.3f' %cij[3,3]
    dat['C45'] = '%.3f' %cij[3,4]
    dat['C46'] = '%.3f' %cij[3,5]
    dat['C51'] = '%.3f' %cij[4,0]
    dat['C52'] = '%.3f' %cij[4,1]
    dat['C53'] = '%.3f' %cij[4,2]
    dat['C54'] = '%.3f' %cij[4,3]
    dat['C55'] = '%.3f' %cij[4,4]
    dat['C56'] = '%.3f' %cij[4,5]
    dat['C61'] = '%.3f' %cij[5,0]
    dat['C62'] = '%.3f' %cij[5,1]
    dat['C63'] = '%.3f' %cij[5,2]
    dat['C64'] = '%.3f' %cij[5,3]
    dat['C65'] = '%.3f' %cij[5,4]
    dat['C66'] = '%.3f' %cij[5,5]
    data.append(deepcopy(dat))

    dat['straindirection'] = 'negative'
    cij = uc.get_in_units(record.raw_cij_negative, 'GPa')
    dat['C11'] = '%.3f' %cij[0,0]
    dat['C12'] = '%.3f' %cij[0,1]
    dat['C13'] = '%.3f' %cij[0,2]
    dat['C14'] = '%.3f' %cij[0,3]
    dat['C15'] = '%.3f' %cij[0,4]
    dat['C16'] = '%.3f' %cij[0,5]
    dat['C21'] = '%.3f' %cij[1,0]
    dat['C22'] = '%.3f' %cij[1,1]
    dat['C23'] = '%.3f' %cij[1,2]
    dat['C24'] = '%.3f' %cij[1,3]
    dat['C25'] = '%.3f' %cij[1,4]
    dat['C26'] = '%.3f' %cij[1,5]
    dat['C31'] = '%.3f' %cij[2,0]
    dat['C32'] = '%.3f' %cij[2,1]
    dat['C33'] = '%.3f' %cij[2,2]
    dat['C34'] = '%.3f' %cij[2,3]
    dat['C35'] = '%.3f' %cij[2,4]
    dat['C36'] = '%.3f' %cij[2,5]
    dat['C41'] = '%.3f' %cij[3,0]
    dat['C42'] = '%.3f' %cij[3,1]
    dat['C43'] = '%.3f' %cij[3,2]
    dat['C44'] = '%.3f' %cij[3,3]
    dat['C45'] = '%.3f' %cij[3,4]
    dat['C46'] = '%.3f' %cij[3,5]
    dat['C51'] = '%.3f' %cij[4,0]
    dat['C52'] = '%.3f' %cij[4,1]
    dat['C53'] = '%.3f' %cij[4,2]
    dat['C54'] = '%.3f' %cij[4,3]
    dat['C55'] = '%.3f' %cij[4,4]
    dat['C56'] = '%.3f' %cij[4,5]
    dat['C61'] = '%.3f' %cij[5,0]
    dat['C62'] = '%.3f' %cij[5,1]
    dat['C63'] = '%.3f' %cij[5,2]
    dat['C64'] = '%.3f' %cij[5,3]
    dat['C65'] = '%.3f' %cij[5,4]
    dat['C66'] = '%.3f' %cij[5,5]
    data.append(deepcopy(dat))

columns = ['calc_key', 'potential_LAMMPS_key', 'potential_LAMMPS_id', 'potential_key', 'potential_id',
           'composition', 'prototype', 'family', 
           'a', 'b', 'c', 'alpha', 'beta', 'gamma',
           'strainrange', 'straindirection', 
           'C11', 'C12', 'C13', 'C14', 'C15', 'C16',
           'C21', 'C22', 'C23', 'C24', 'C25', 'C26',
           'C31', 'C32', 'C33', 'C34', 'C35', 'C36',
           'C41', 'C42', 'C43', 'C44', 'C45', 'C46',
           'C51', 'C52', 'C53', 'C54', 'C55', 'C56',
           'C61', 'C62', 'C63', 'C64', 'C65', 'C66']

data = pd.DataFrame(data, columns=columns).sort_values(['potential_LAMMPS_id', 'composition', 'prototype', 'strainrange', 'straindirection'])

# %%
data.to_csv('elastic-constants.csv')

# %% [markdown]
# ### Save raw crystal-specific data

# %%
for implememtation_key in np.unique(data.potential_LAMMPS_key):
    imp_results = data[data.potential_LAMMPS_key == implememtation_key]
    potential = imp_results.iloc[0].potential_id
    implementation = imp_results.iloc[0].potential_LAMMPS_id
    
    contentpath = os.path.join(outputpath, potential, implementation)
    if not os.path.isdir(contentpath):
        os.makedirs(contentpath)
    
    for composition in np.unique(imp_results.composition):
        comp_results = imp_results[imp_results.composition == composition].sort_values(['family', 'a', 'strainrange', 'straindirection'])
        fstem = 'elastic.' + composition
        
        comp_results.to_csv(os.path.join(contentpath, fstem + '.csv'), index=False)

# %% [markdown]
# ### Add info to PotentialProperties records
#
# This is for generating XML records that the Interatomic Potential Repository uses to automatically build webcontent (done elsewhere).

# %%
# Add calculation data to PotentialProperties records
for implememtation_key in np.unique(data.potential_LAMMPS_key):
    imp_records = data[data.potential_LAMMPS_key == implememtation_key].sort_values('family')
    pot_record = pot_records[pot_records.key == implememtation_key].iloc[0]
    implementation_id = pot_record.id
    potential_id = pot_record.pot_id
    potential_key = pot_record.pot_key
    
    record_name = 'properties.' + implementation_id
    try:
        record = database.get_record(name=record_name, style='PotentialProperties')
    except:
        new = True
        content = DM()
        content['per-potential-properties'] = DM()
        content['per-potential-properties']['potential'] = DM()
        content['per-potential-properties']['potential']['key'] = potential_key
        content['per-potential-properties']['potential']['id'] = potential_id
        content['per-potential-properties']['implementation'] = DM()
        content['per-potential-properties']['implementation']['key'] = implememtation_key
        content['per-potential-properties']['implementation']['id'] = implementation_id
    else:
        content = DM(record.content)
        new = False
    
    content['per-potential-properties']['elastic-constants'] = ec_model = DM()
    
    for composition in np.unique(imp_records.composition):
        comp_records = imp_records[imp_records.composition == composition]
        comp_model = DM()
        comp_model['composition'] = composition
        
        for prototype in np.unique(comp_records.prototype):
            proto_records = comp_records[comp_records.prototype == prototype]
            proto_model = DM()
            proto_model['prototype'] = prototype
            
            for alat in np.unique(proto_records.a):
                alat_records = proto_records[proto_records.a == alat]
                alat_model = DM()
                alat_model['a'] = alat
                
                for series in alat_records.sort_values(['strainrange', 'straindirection']).itertuples():
                    measurement = DM()
                    if series.straindirection == 'positive':
                        measurement['strain'] = '+%s' %series.strainrange
                    elif series.straindirection == 'negative':
                        measurement['strain'] = '-%s' %series.strainrange
                    else:
                        raise ValueError('Unknown straindirection')
                    measurement['C11'] = series.C11
                    measurement['C12'] = series.C12
                    measurement['C13'] = series.C13
                    measurement['C14'] = series.C14
                    measurement['C15'] = series.C15
                    measurement['C16'] = series.C16
                    measurement['C21'] = series.C21
                    measurement['C22'] = series.C22
                    measurement['C23'] = series.C23
                    measurement['C24'] = series.C24
                    measurement['C25'] = series.C25
                    measurement['C26'] = series.C26
                    measurement['C31'] = series.C31
                    measurement['C32'] = series.C32
                    measurement['C33'] = series.C33
                    measurement['C34'] = series.C34
                    measurement['C35'] = series.C35
                    measurement['C36'] = series.C36
                    measurement['C41'] = series.C41
                    measurement['C42'] = series.C42
                    measurement['C43'] = series.C43
                    measurement['C44'] = series.C44
                    measurement['C45'] = series.C45
                    measurement['C46'] = series.C46
                    measurement['C51'] = series.C51
                    measurement['C52'] = series.C52
                    measurement['C53'] = series.C53
                    measurement['C54'] = series.C54
                    measurement['C55'] = series.C55
                    measurement['C56'] = series.C56
                    measurement['C61'] = series.C61
                    measurement['C62'] = series.C62
                    measurement['C63'] = series.C63
                    measurement['C64'] = series.C64
                    measurement['C65'] = series.C65
                    measurement['C66'] = series.C66
                    
                    alat_model.append('measurement', measurement)
                proto_model.append('alats', alat_model)
            comp_model.append('prototypes', proto_model)
        ec_model.append('compositions', comp_model)
    
    if new:
        database.add_record(name=record_name, style='PotentialProperties', content=content.xml())
    else:
        database.update_record(record=record, content=content.xml())
