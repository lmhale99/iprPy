# %% [markdown]
# # Static elastic constants
# This Notebook follows the workflow for setting up, running, and processing the elastic_constants_static calculations.
#
# **Quick Notes:**
#
# - All input scripts take key-value pairs where the "key"s correspond to the calculation's input parameters.
#
# - Multiple calculations are prepared by specifying multiple values for the same key (on separate lines).
#
# - The special "buildcombos" key accesses predefined functions for generating lists of input parameter values for certain sets of keys.  See documentation for more details.

# %% [markdown]
# __Global workflow details:__
#
# This Notebook requires calculation_crystal_space_group records and the "unique_crystals.csv" file, both of which are generated by the "3. Crystal relaxation" Notebook.
#
# The calculation_elastic_constants_static records generated are used as inputs for dislocation creation Notebooks.

# %% [markdown]
# **Library imports**

# %%
# Standard Python libraries
from __future__ import (absolute_import, print_function,
                        division, unicode_literals)
import os
from datetime import date
from math import floor
from copy import deepcopy

# http://www.numpy.org/
import numpy as np

# https://pandas.pydata.org/
import pandas as pd

# https://bokeh.pydata.org/
import bokeh
import bokeh.plotting
import bokeh.resources
import bokeh.io
import bokeh.models

from DataModelDict import DataModelDict as DM

# https://github.com/usnistgov/atomman
import atomman.unitconvert as uc

# https://github.com/usnistgov/iprPy
import iprPy
print('iprPy version', iprPy.__version__)
# Out:
# iprPy version 0.8.3

# %% [markdown]
# ## 0. Access database

# %% [markdown]
# ### Load database

# %%
database = iprPy.load_database('potential_testing')

# %% [markdown]
# ### Load unique crystals

# %%
unique_crystals = pd.read_csv('unique_crystals.csv')
print(len(unique_crystals))
# Out:
# 15

# %% [markdown]
# ### Limit unique crystals to include (optional)

# %%
#unique_crystals = unique_crystals[unique_crystals.potential_LAMMPS_id == '2012--Park-H--Mo--LAMMPS--ipr1']
#unique_crystals = unique_crystals[unique_crystals.composition == '']
#unique_crystals = unique_crystals[unique_crystals.prototype == '']
print(len(unique_crystals))
# Out:
# 15

# %% [markdown]
# ## 1. Run elastic_constants_static calculations
#
# This calculation evaluates the elastic constants for a crystal using small strain deformations.

# %%
calculation = iprPy.load_calculation('elastic_constants_static')
run_directory = iprPy.load_run_directory('potential_testing_1')

# %% [markdown]
# ### Show calculation's allowed keys
#
# These are the keys that the input script will accept.

# %%
print(calculation.allkeys)
# Out:
# ['lammps_command', 'mpi_command', 'length_unit', 'pressure_unit', 'energy_unit', 'force_unit', 'potential_file', 'potential_content', 'potential_dir', 'load_file', 'load_content', 'load_style', 'family', 'load_options', 'symbols', 'box_parameters', 'a_uvw', 'b_uvw', 'c_uvw', 'atomshift', 'sizemults', 'strainrange', 'energytolerance', 'forcetolerance', 'maxiterations', 'maxevaluations', 'maxatommotion']

# %% [markdown]
# ### Write input script

# %%
input_script = """
# Commands and executables
lammps_command              lmp_mpi
mpi_command                 

# Build load information from crystal_space_group results
buildcombos                 atomicparent load_file parent
parent_record               calculation_crystal_space_group
parent_load_key             unit-cell-atomic-system

# System manipulations
a_uvw                      
b_uvw                      
c_uvw                 
atomshift                   
sizemults                   5 5 5

# Units that input/output values are in
length_unit                 
pressure_unit               
energy_unit                 
force_unit                  

# Run parameters
energytolerance             
forcetolerance              
maxiterations               
maxevaluations              
maxatommotion               
strainrange                  1e-5
strainrange                  1e-6
strainrange                  1e-7
strainrange                  1e-8
"""

with open('input_script.in', 'w') as f:
    f.write(input_script)

# %% [markdown]
# ### Parse input script

# %%
with open('input_script.in') as f:
    input_dict = iprPy.input.parse(f, singularkeys=calculation.singularkeys)

# %% [markdown]
# ### Add parent_name list using unique crystals

# %%
input_dict['parent_name'] = unique_crystals.calc_key.tolist()

# %% [markdown]
# ### Prepare calculations

# %%
database.prepare(run_directory, calculation, **input_dict)

# %%
database.check_records(calculation.record_style)
# Out:
# In database style local at C:\Users\lmh1\Documents\calculations\ipr\potential_testing :
# - 60 of style calculation_elastic_constants_static
#  - 0 are complete
#  - 60 still to run
#  - 0 issued errors

# %% [markdown]
# ### Run calculations

# %%
database.runner(run_directory)
# Out:
# Runner started with pid 9940
# No simulations left to run

# %%
results_df = database.get_records_df(style=calculation.record_style)
error_df = results_df[results_df.status=='error']
print(len(error_df), 'calculations issued errors:')
errors = []
for error in error_df.error:
    lines = error.splitlines()
    err = ''
    for i in range(len(lines)-1, -1, -1):
        if 'Error:' in lines[i]:
            err = '\n'.join(lines[i:-1])
            break
        if i == 0:
            err = error
    errors.append(err)
for error in np.unique(errors):
    print(error)
# Out:
# 4 calculations issued errors:
# ValueError: Invalid LAMMPS input:
# Last command: read_restart initial.restart

# %% [markdown]
# ## 2. Calculation analysis

# %% [markdown]
# ### Retrieve finished calculation results

# %%
records = database.get_records_df(style='calculation_elastic_constants_static', full=True, flat=False, status='finished')
pot_records = database.get_records_df(style='potential_users_LAMMPS')

# %% [markdown]
# ### Identify compositions

# %%
iprPy.analysis.assign_composition(records, database)

# %%
# Settings
outputpath = 'C:/Users/lmh1/Documents/potential_testing_results'
#savecolumns = ['calc_key', 'composition', 'prototype', 'family', 'a', 
#               'strainrange', '', 'gamma_fs']

# %% [markdown]
# ### Save raw data

# %%
records
# Out:
#                                                     C    LAMMPS_version error  \
# 0   [[0.72412699 0.34635333 0.28219474 0.         ...  26 Jan 2017-ICMS   NaN
# 1   [[0.77528073 0.4289165  0.4289165  0.         ...  26 Jan 2017-ICMS   NaN
# 3   [[ 0.85079137  0.15530357  0.08940042  0.     ...  26 Jan 2017-ICMS   NaN
# 4   [[ 0.39073819  0.38305496 -0.00843477  0.     ...  26 Jan 2017-ICMS   NaN
# 5   [[0.71025763 0.38419452 0.38419452 0.         ...  26 Jan 2017-ICMS   NaN
# 6   [[ 7.63043321e-01  4.37944627e-01  4.37944626e...  26 Jan 2017-ICMS   NaN
# 7   [[0.65662387 0.3923673  0.3923673  0.         ...  26 Jan 2017-ICMS   NaN
# 8   [[ 0.39067656  0.38308282 -0.0084637   0.     ...  26 Jan 2017-ICMS   NaN
# 9   [[ 7.24126990e-01  3.46353333e-01  2.82194744e...  26 Jan 2017-ICMS   NaN
# 10  [[ 7.26972875e-01  3.55561944e-01  3.03938476e...  26 Jan 2017-ICMS   NaN
# 11  [[0.6556217  0.39085772 0.39085772 0.         ...  26 Jan 2017-ICMS   NaN
# 12  [[0.73186637 0.36552692 0.3256204  0.         ...  26 Jan 2017-ICMS   NaN
# 13  [[0.04153435 0.39841886 0.39841886 0.         ...  26 Jan 2017-ICMS   NaN
# 49  [[ 0.18491573  0.21822924  0.21822924  0.     ...  26 Jan 2017-ICMS   NaN
# 50  [[0.65589331 0.39144468 0.39144468 0.         ...  26 Jan 2017-ICMS   NaN
# 51  [[0.65561646 0.39086075 0.39086075 0.         ...  26 Jan 2017-ICMS   NaN
# 52  [[ 8.50791364e-01  1.55303566e-01  8.94004175e...  26 Jan 2017-ICMS   NaN
# 53  [[1.28813323 0.5239959  0.5239959  0.         ...  26 Jan 2017-ICMS   NaN
# 54  [[1.28813323 0.5239959  0.5239959  0.         ...  26 Jan 2017-ICMS   NaN
# 55  [[0.76498218 0.41589691 0.41589691 0.         ...  26 Jan 2017-ICMS   NaN
# 56  [[0.72412699 0.34635333 0.28219474 0.         ...  26 Jan 2017-ICMS   NaN
# 57  [[3.65128200e-01 8.54179858e-02 8.54179826e-02...  26 Jan 2017-ICMS   NaN
# 58  [[ 7.25863092e-01  3.57308974e-01  3.04415722e...  26 Jan 2017-ICMS   NaN
# 59  [[ 4.15343478e-02  3.98418855e-01  3.98418856e...  26 Jan 2017-ICMS   NaN
#
#                        family iprPy_version  \
# 0                oqmd-1215215         0.8.3
# 1                oqmd-1214770         0.8.3
# 3                 A5--beta-Sn         0.8.3
# 4                oqmd-1214681         0.8.3
# 5                 A1--Cu--fcc         0.8.3
# 6                oqmd-1214770         0.8.3
# 7                oqmd-1214859         0.8.3
# 8                oqmd-1214681         0.8.3
# 9                oqmd-1215215         0.8.3
# 10               oqmd-1216017         0.8.3
# 11               oqmd-1214859         0.8.3
# 12  A3'--alpha-La--double-hcp         0.8.3
# 13                 A2--W--bcc         0.8.3
# 15                A5--beta-Sn         0.8.3
# 16                A1--Cu--fcc         0.8.3
# 17                  A4--C--dc         0.8.3
# 18               oqmd-1214859         0.8.3
# 19                A1--Cu--fcc         0.8.3
# 20               oqmd-1214770         0.8.3
# 21               oqmd-1214681         0.8.3
# 22                A15--beta-W         0.8.3
# 23                A5--beta-Sn         0.8.3
# 24               oqmd-1214770         0.8.3
# 25               oqmd-1214770         0.8.3
# 26               oqmd-1216017         0.8.3
# 27               oqmd-1214770         0.8.3
# 28  A3'--alpha-La--double-hcp         0.8.3
# 29                  A4--C--dc         0.8.3
# 30                  A4--C--dc         0.8.3
# 31               oqmd-1214859         0.8.3
# 33                 A2--W--bcc         0.8.3
# 34                 A2--W--bcc         0.8.3
# 35  A3'--alpha-La--double-hcp         0.8.3
# 36  A3'--alpha-La--double-hcp         0.8.3
# 37               oqmd-1214770         0.8.3
# 38               oqmd-1214859         0.8.3
# 39                A1--Cu--fcc         0.8.3
# 40           Ah--alpha-Po--sc         0.8.3
# 42           Ah--alpha-Po--sc         0.8.3
# 43           Ah--alpha-Po--sc         0.8.3
# 44               oqmd-1215215         0.8.3
# 45               oqmd-1214681         0.8.3
# 46               oqmd-1216017         0.8.3
# 47                A15--beta-W         0.8.3
# 48           Ah--alpha-Po--sc         0.8.3
# 49                  A4--C--dc         0.8.3
# 50               oqmd-1214859         0.8.3
# 51               oqmd-1214859         0.8.3
# 52                A5--beta-Sn         0.8.3
# 53                A15--beta-W         0.8.3
# 54                A15--beta-W         0.8.3
# 55               oqmd-1214770         0.8.3
# 52  dc8f8afe-60e2-4e55-bee8-da403d923e0d
# 53  e12940dc-1099-43c6-b72a-8c68b74f4101
# 54  e1adda4e-2036-46a1-aeeb-cbfa2df8c566
# 55  e2f71da5-e600-4fcf-8be9-19b2e9efa6a1
# 56  e79f2810-3ad9-4b67-bdbe-31e2e07d85b6
# 57  f1ba4fdb-a676-458a-928f-26ce7ed3a39a
# 58  fbd9303c-e333-41e4-83d6-25b703618f00
# 59  ff7c9252-4027-47eb-bb3e-a8611542aa0b
#
#                                     load_file                 load_options  \
# 0   b0ffec08-bb68-4ca4-9608-d5d259985078.json  key unit-cell-atomic-system
# 1   2784b307-7960-457c-9901-d495ce493e92.json  key unit-cell-atomic-system
# 3   42610089-f823-4d79-9402-65161599ad0c.json  key unit-cell-atomic-system
# 4   4c4cccea-2d40-4635-b171-c18048f2679f.json  key unit-cell-atomic-system
# 5   7c0c7d7e-3b04-4609-8aaa-97965e15d509.json  key unit-cell-atomic-system
# 6   649d7093-d649-4df3-958c-a7ed224053d9.json  key unit-cell-atomic-system
# 7   7374cb15-6cd9-499f-847d-07b9f23c9678.json  key unit-cell-atomic-system
# 8   4c4cccea-2d40-4635-b171-c18048f2679f.json  key unit-cell-atomic-system
# 9   b0ffec08-bb68-4ca4-9608-d5d259985078.json  key unit-cell-atomic-system
# 10  4ac2c55a-5608-4613-a008-725cebbbb793.json  key unit-cell-atomic-system
# 11  b1d1c5fe-a416-4bff-9b37-895d6fb433ea.json  key unit-cell-atomic-system
# 12  2c13f553-eda9-47a8-8395-6d79879e61f7.json  key unit-cell-atomic-system
# 13  eddaafd7-fb31-4e56-a35d-d1a2fe828155.json  key unit-cell-atomic-system
# 15  42610089-f823-4d79-9402-65161599ad0c.json  key unit-cell-atomic-system
# 16  7c0c7d7e-3b04-4609-8aaa-97965e15d509.json  key unit-cell-atomic-system
# 17  e5294688-e472-4c4b-8833-7b921f195dc1.json  key unit-cell-atomic-system
# 18  b1d1c5fe-a416-4bff-9b37-895d6fb433ea.json  key unit-cell-atomic-system
# 19  7c0c7d7e-3b04-4609-8aaa-97965e15d509.json  key unit-cell-atomic-system
# 20  2784b307-7960-457c-9901-d495ce493e92.json  key unit-cell-atomic-system
# 21  4c4cccea-2d40-4635-b171-c18048f2679f.json  key unit-cell-atomic-system
# 22  1acc1a05-c222-4e61-8aae-8a3eea8bc8e6.json  key unit-cell-atomic-system
# 23  42610089-f823-4d79-9402-65161599ad0c.json  key unit-cell-atomic-system
# 24  2784b307-7960-457c-9901-d495ce493e92.json  key unit-cell-atomic-system
# 25  649d7093-d649-4df3-958c-a7ed224053d9.json  key unit-cell-atomic-system
# 26  4ac2c55a-5608-4613-a008-725cebbbb793.json  key unit-cell-atomic-system
# 27  649d7093-d649-4df3-958c-a7ed224053d9.json  key unit-cell-atomic-system
# 28  2c13f553-eda9-47a8-8395-6d79879e61f7.json  key unit-cell-atomic-system
# 29  e5294688-e472-4c4b-8833-7b921f195dc1.json  key unit-cell-atomic-system
# 30  e5294688-e472-4c4b-8833-7b921f195dc1.json  key unit-cell-atomic-system
# 31  7374cb15-6cd9-499f-847d-07b9f23c9678.json  key unit-cell-atomic-system
# 33  eddaafd7-fb31-4e56-a35d-d1a2fe828155.json  key unit-cell-atomic-system
# 34  eddaafd7-fb31-4e56-a35d-d1a2fe828155.json  key unit-cell-atomic-system
# 35  2c13f553-eda9-47a8-8395-6d79879e61f7.json  key unit-cell-atomic-system
# 36  2c13f553-eda9-47a8-8395-6d79879e61f7.json  key unit-cell-atomic-system
# 37  2784b307-7960-457c-9901-d495ce493e92.json  key unit-cell-atomic-system
# 38  7374cb15-6cd9-499f-847d-07b9f23c9678.json  key unit-cell-atomic-system
# 39  7c0c7d7e-3b04-4609-8aaa-97965e15d509.json  key unit-cell-atomic-system
# 40  78df7eb0-fdd5-45e4-acd4-12f9afb4792a.json  key unit-cell-atomic-system
# 42  78df7eb0-fdd5-45e4-acd4-12f9afb4792a.json  key unit-cell-atomic-system
# 43  78df7eb0-fdd5-45e4-acd4-12f9afb4792a.json  key unit-cell-atomic-system
# 44  b0ffec08-bb68-4ca4-9608-d5d259985078.json  key unit-cell-atomic-system
# 45  4c4cccea-2d40-4635-b171-c18048f2679f.json  key unit-cell-atomic-system
# 46  4ac2c55a-5608-4613-a008-725cebbbb793.json  key unit-cell-atomic-system
# 47  1acc1a05-c222-4e61-8aae-8a3eea8bc8e6.json  key unit-cell-atomic-system
# 48  78df7eb0-fdd5-45e4-acd4-12f9afb4792a.json  key unit-cell-atomic-system
# 49  e5294688-e472-4c4b-8833-7b921f195dc1.json  key unit-cell-atomic-system
# 50  b1d1c5fe-a416-4bff-9b37-895d6fb433ea.json  key unit-cell-atomic-system
# 51  b1d1c5fe-a416-4bff-9b37-895d6fb433ea.json  key unit-cell-atomic-system
# 52  42610089-f823-4d79-9402-65161599ad0c.json  key unit-cell-atomic-system
# 53  1acc1a05-c222-4e61-8aae-8a3eea8bc8e6.json  key unit-cell-atomic-system
# 54  1acc1a05-c222-4e61-8aae-8a3eea8bc8e6.json  key unit-cell-atomic-system
# 55  649d7093-d649-4df3-958c-a7ed224053d9.json  key unit-cell-atomic-system
# 56  b0ffec08-bb68-4ca4-9608-d5d259985078.json  key unit-cell-atomic-system
# 57  7374cb15-6cd9-499f-847d-07b9f23c9678.json  key unit-cell-atomic-system
# 58  4ac2c55a-5608-4613-a008-725cebbbb793.json  key unit-cell-atomic-system
# 59  eddaafd7-fb31-4e56-a35d-d1a2fe828155.json  key unit-cell-atomic-system
#
#       load_style                   potential_LAMMPS_id     ...      \
# 0   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 1   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 3   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 4   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 5   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 6   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 7   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 8   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 9   system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 10  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 11  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 12  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 13  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 15  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 16  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 17  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 18  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 19  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 20  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 21  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 22  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 23  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 24  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 25  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 26  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 27  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 28  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 29  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 30  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 31  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 33  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 34  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 35  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 36  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 37  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 38  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 39  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 40  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 42  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 43  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 44  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 45  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 46  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 47  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 48  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 49  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 50  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 51  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 52  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 53  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 54  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 55  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 56  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 57  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 58  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
# 59  system_model  1999--Mishin-Y--Al--LAMMPS--testing1     ...
#
#           potential_id                         potential_key  \
# 0   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 1   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 3   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 4   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 5   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 6   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 7   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 8   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 9   1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 10  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 11  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 12  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 13  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 15  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 16  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 17  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 18  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 19  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 20  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 21  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 22  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
# 23  1999--Mishin-Y--Al  eb33d631-9ac6-4b51-8642-7a92462b96a3
#
# 46  [[0.7258627203640194, 0.35731051521691065, 0.3...
# 47  [[1.288133199472476, 0.5239958871436057, 0.523...
# 48  [[0.6766512332138825, 0.008396571427179346, 0....
# 49  [[0.18491299591278176, 0.21822884626692968, 0....
# 50  [[0.6558837387347505, 0.3914389774178854, 0.39...
# 51  [[0.6556135925254157, 0.3908588623752464, 0.39...
# 52  [[0.8507911851723702, 0.15530349871731586, 0.0...
# 53  [[1.2881301615597829, 0.5239945020860346, 0.52...
# 54  [[1.288132923643517, 0.5239957593058485, 0.523...
# 55  [[0.7648673548011925, 0.4161711980052527, 0.41...
# 56  [[0.7241267787111714, 0.3463532648350852, 0.28...
# 57  [[0.7035933583367584, 0.38984851835448253, 0.3...
# 58  [[0.7258354287563605, 0.35730114427659787, 0.3...
# 59  [[0.041534355351313515, 0.39841885164752955, 0...
#
#                            script                 sizemults    status  \
# 0   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 1   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 3   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 4   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 5   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 6   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 7   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 8   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 9   calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 10  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 11  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 12  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 13  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 15  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 16  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 17  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 18  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 19  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 20  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 21  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 22  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 23  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 24  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 25  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 26  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 27  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 28  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 29  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 30  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 31  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 33  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 34  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 35  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 36  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 37  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 38  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 39  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 40  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 42  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 43  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 44  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 45  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 46  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 47  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 48  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 49  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 50  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 51  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 52  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 53  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 54  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 55  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 56  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 57  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 58  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
# 59  calc_elastic_constants_static  [[0, 5], [0, 5], [0, 5]]  finished
#
#      strainrange  symbols composition
# 0   1.000000e-06     [Al]          Al
# 1   1.000000e-06     [Al]          Al
# 3   1.000000e-07     [Al]          Al
# 4   1.000000e-06     [Al]          Al
# 5   1.000000e-07     [Al]          Al
# 6   1.000000e-08     [Al]          Al
# 7   1.000000e-07     [Al]          Al
# 8   1.000000e-07     [Al]          Al
# 9   1.000000e-08     [Al]          Al
# 10  1.000000e-08     [Al]          Al
# 11  1.000000e-05     [Al]          Al
# 12  1.000000e-07     [Al]          Al
# 13  1.000000e-06     [Al]          Al
# 15  1.000000e-06     [Al]          Al
# 16  1.000000e-08     [Al]          Al
# 17  1.000000e-08     [Al]          Al
# 18  1.000000e-08     [Al]          Al
# 19  1.000000e-05     [Al]          Al
# 20  1.000000e-07     [Al]          Al
# 21  1.000000e-08     [Al]          Al
# 22  1.000000e-05     [Al]          Al
# 23  1.000000e-05     [Al]          Al
# 24  1.000000e-05     [Al]          Al
# 25  1.000000e-06     [Al]          Al
# 26  1.000000e-07     [Al]          Al
# 27  1.000000e-07     [Al]          Al
# 28  1.000000e-05     [Al]          Al
# 29  1.000000e-07     [Al]          Al
# 30  1.000000e-05     [Al]          Al
# 31  1.000000e-06     [Al]          Al
# 33  1.000000e-07     [Al]          Al
# 34  1.000000e-05     [Al]          Al
# 35  1.000000e-06     [Al]          Al
# 36  1.000000e-08     [Al]          Al
# 37  1.000000e-08     [Al]          Al
# 38  1.000000e-05     [Al]          Al
# 39  1.000000e-06     [Al]          Al
# 40  1.000000e-07     [Al]          Al
# 42  1.000000e-05     [Al]          Al
# 43  1.000000e-08     [Al]          Al
# 44  1.000000e-05     [Al]          Al
# 45  1.000000e-05     [Al]          Al
# 46  1.000000e-06     [Al]          Al
# 47  1.000000e-08     [Al]          Al
# 48  1.000000e-06     [Al]          Al
# 49  1.000000e-06     [Al]          Al
# 50  1.000000e-07     [Al]          Al
# 51  1.000000e-06     [Al]          Al
# 52  1.000000e-08     [Al]          Al
# 53  1.000000e-06     [Al]          Al
# 54  1.000000e-07     [Al]          Al
# 55  1.000000e-05     [Al]          Al
# 56  1.000000e-07     [Al]          Al
# 57  1.000000e-08     [Al]          Al
# 58  1.000000e-05     [Al]          Al
# 59  1.000000e-08     [Al]          Al
#
# [56 rows x 21 columns]

# %%
data = []
for record in records.itertuples():
    crystal = unique_crystals[unique_crystals.calc_key == record.load_file.split('.')[0]].iloc[0]
    
    dat = {}
    dat['calc_key'] = record.key
    dat['potential_LAMMPS_key'] = crystal.potential_LAMMPS_key
    dat['potential_LAMMPS_id'] = crystal.potential_LAMMPS_id
    dat['potential_key'] = crystal.potential_key
    dat['potential_id'] = crystal.potential_id
    dat['prototype'] = crystal.prototype
    dat['family'] = crystal.family
    dat['composition'] = record.composition
    dat['strainrange'] = record.strainrange
    dat['a'] = crystal.a
    dat['b'] = crystal.b
    dat['c'] = crystal.c
    dat['alpha'] = crystal.alpha
    dat['beta'] = crystal.beta
    dat['gamma'] = crystal.gamma

    dat['straindirection'] = 'positive'
    cij = uc.get_in_units(record.raw_cij_positive, 'GPa')
    dat['C11'] = '%.3f' %cij[0,0]
    dat['C12'] = '%.3f' %cij[0,1]
    dat['C13'] = '%.3f' %cij[0,2]
    dat['C14'] = '%.3f' %cij[0,3]
    dat['C15'] = '%.3f' %cij[0,4]
    dat['C16'] = '%.3f' %cij[0,5]
    dat['C21'] = '%.3f' %cij[1,0]
    dat['C22'] = '%.3f' %cij[1,1]
    dat['C23'] = '%.3f' %cij[1,2]
    dat['C24'] = '%.3f' %cij[1,3]
    dat['C25'] = '%.3f' %cij[1,4]
    dat['C26'] = '%.3f' %cij[1,5]
    dat['C31'] = '%.3f' %cij[2,0]
    dat['C32'] = '%.3f' %cij[2,1]
    dat['C33'] = '%.3f' %cij[2,2]
    dat['C34'] = '%.3f' %cij[2,3]
    dat['C35'] = '%.3f' %cij[2,4]
    dat['C36'] = '%.3f' %cij[2,5]
    dat['C41'] = '%.3f' %cij[3,0]
    dat['C42'] = '%.3f' %cij[3,1]
    dat['C43'] = '%.3f' %cij[3,2]
    dat['C44'] = '%.3f' %cij[3,3]
    dat['C45'] = '%.3f' %cij[3,4]
    dat['C46'] = '%.3f' %cij[3,5]
    dat['C51'] = '%.3f' %cij[4,0]
    dat['C52'] = '%.3f' %cij[4,1]
    dat['C53'] = '%.3f' %cij[4,2]
    dat['C54'] = '%.3f' %cij[4,3]
    dat['C55'] = '%.3f' %cij[4,4]
    dat['C56'] = '%.3f' %cij[4,5]
    dat['C61'] = '%.3f' %cij[5,0]
    dat['C62'] = '%.3f' %cij[5,1]
    dat['C63'] = '%.3f' %cij[5,2]
    dat['C64'] = '%.3f' %cij[5,3]
    dat['C65'] = '%.3f' %cij[5,4]
    dat['C66'] = '%.3f' %cij[5,5]
    data.append(deepcopy(dat))

    dat['straindirection'] = 'negative'
    cij = uc.get_in_units(record.raw_cij_negative, 'GPa')
    dat['C11'] = '%.3f' %cij[0,0]
    dat['C12'] = '%.3f' %cij[0,1]
    dat['C13'] = '%.3f' %cij[0,2]
    dat['C14'] = '%.3f' %cij[0,3]
    dat['C15'] = '%.3f' %cij[0,4]
    dat['C16'] = '%.3f' %cij[0,5]
    dat['C21'] = '%.3f' %cij[1,0]
    dat['C22'] = '%.3f' %cij[1,1]
    dat['C23'] = '%.3f' %cij[1,2]
    dat['C24'] = '%.3f' %cij[1,3]
    dat['C25'] = '%.3f' %cij[1,4]
    dat['C26'] = '%.3f' %cij[1,5]
    dat['C31'] = '%.3f' %cij[2,0]
    dat['C32'] = '%.3f' %cij[2,1]
    dat['C33'] = '%.3f' %cij[2,2]
    dat['C34'] = '%.3f' %cij[2,3]
    dat['C35'] = '%.3f' %cij[2,4]
    dat['C36'] = '%.3f' %cij[2,5]
    dat['C41'] = '%.3f' %cij[3,0]
    dat['C42'] = '%.3f' %cij[3,1]
    dat['C43'] = '%.3f' %cij[3,2]
    dat['C44'] = '%.3f' %cij[3,3]
    dat['C45'] = '%.3f' %cij[3,4]
    dat['C46'] = '%.3f' %cij[3,5]
    dat['C51'] = '%.3f' %cij[4,0]
    dat['C52'] = '%.3f' %cij[4,1]
    dat['C53'] = '%.3f' %cij[4,2]
    dat['C54'] = '%.3f' %cij[4,3]
    dat['C55'] = '%.3f' %cij[4,4]
    dat['C56'] = '%.3f' %cij[4,5]
    dat['C61'] = '%.3f' %cij[5,0]
    dat['C62'] = '%.3f' %cij[5,1]
    dat['C63'] = '%.3f' %cij[5,2]
    dat['C64'] = '%.3f' %cij[5,3]
    dat['C65'] = '%.3f' %cij[5,4]
    dat['C66'] = '%.3f' %cij[5,5]
    data.append(deepcopy(dat))

columns = ['calc_key', 'potential_LAMMPS_key', 'potential_LAMMPS_id', 'potential_key', 'potential_id',
           'composition', 'prototype', 'family', 
           'a', 'b', 'c', 'alpha', 'beta', 'gamma',
           'strainrange', 'straindirection', 
           'C11', 'C12', 'C13', 'C14', 'C15', 'C16',
           'C21', 'C22', 'C23', 'C24', 'C25', 'C26',
           'C31', 'C32', 'C33', 'C34', 'C35', 'C36',
           'C41', 'C42', 'C43', 'C44', 'C45', 'C46',
           'C51', 'C52', 'C53', 'C54', 'C55', 'C56',
           'C61', 'C62', 'C63', 'C64', 'C65', 'C66']

data = pd.DataFrame(data, columns=columns).sort_values(['potential_LAMMPS_id', 'composition', 'prototype', 'strainrange', 'straindirection'])

# %%
data.to_csv('elastic-constants.csv')

# %% [markdown]
# ### Save raw crystal-specific data

# %%
for implememtation_key in np.unique(data.potential_LAMMPS_key):
    imp_results = data[data.potential_LAMMPS_key == implememtation_key]
    potential = imp_results.iloc[0].potential_id
    implementation = imp_results.iloc[0].potential_LAMMPS_id
    
    contentpath = os.path.join(outputpath, potential, implementation)
    if not os.path.isdir(contentpath):
        os.makedirs(contentpath)
    
    for composition in np.unique(imp_results.composition):
        comp_results = imp_results[imp_results.composition == composition].sort_values(['family', 'a', 'strainrange', 'straindirection'])
        fstem = 'elastic.' + composition
        
        comp_results.to_csv(os.path.join(contentpath, fstem + '.csv'), index=False)

# %% [markdown]
# ### Add info to PotentialProperties records
#
# This is for generating XML records that the Interatomic Potential Repository uses to automatically build webcontent (done elsewhere).

# %%
# Add calculation data to PotentialProperties records
for implememtation_key in np.unique(data.potential_LAMMPS_key):
    imp_records = data[data.potential_LAMMPS_key == implememtation_key].sort_values('family')
    pot_record = pot_records[pot_records.key == implememtation_key].iloc[0]
    implementation_id = pot_record.id
    potential_id = pot_record.pot_id
    potential_key = pot_record.pot_key
    
    record_name = 'properties.' + implementation_id
    try:
        record = database.get_record(name=record_name, style='PotentialProperties')
    except:
        new = True
        content = DM()
        content['per-potential-properties'] = DM()
        content['per-potential-properties']['potential'] = DM()
        content['per-potential-properties']['potential']['key'] = potential_key
        content['per-potential-properties']['potential']['id'] = potential_id
        content['per-potential-properties']['implementation'] = DM()
        content['per-potential-properties']['implementation']['key'] = implememtation_key
        content['per-potential-properties']['implementation']['id'] = implementation_id
    else:
        content = DM(record.content)
        new = False
    
    content['per-potential-properties']['elastic-constants'] = ec_model = DM()
    
    for composition in np.unique(imp_records.composition):
        comp_records = imp_records[imp_records.composition == composition]
        comp_model = DM()
        comp_model['composition'] = composition
        
        for prototype in np.unique(comp_records.prototype):
            proto_records = comp_records[comp_records.prototype == prototype]
            proto_model = DM()
            proto_model['prototype'] = prototype
            
            for alat in np.unique(proto_records.a):
                alat_records = proto_records[proto_records.a == alat]
                alat_model = DM()
                alat_model['a'] = alat
                
                for series in alat_records.sort_values(['strainrange', 'straindirection']).itertuples():
                    measurement = DM()
                    if series.straindirection == 'positive':
                        measurement['strain'] = '+%s' %series.strainrange
                    elif series.straindirection == 'negative':
                        measurement['strain'] = '-%s' %series.strainrange
                    else:
                        raise ValueError('Unknown straindirection')
                    measurement['C11'] = series.C11
                    measurement['C12'] = series.C12
                    measurement['C13'] = series.C13
                    measurement['C14'] = series.C14
                    measurement['C15'] = series.C15
                    measurement['C16'] = series.C16
                    measurement['C21'] = series.C21
                    measurement['C22'] = series.C22
                    measurement['C23'] = series.C23
                    measurement['C24'] = series.C24
                    measurement['C25'] = series.C25
                    measurement['C26'] = series.C26
                    measurement['C31'] = series.C31
                    measurement['C32'] = series.C32
                    measurement['C33'] = series.C33
                    measurement['C34'] = series.C34
                    measurement['C35'] = series.C35
                    measurement['C36'] = series.C36
                    measurement['C41'] = series.C41
                    measurement['C42'] = series.C42
                    measurement['C43'] = series.C43
                    measurement['C44'] = series.C44
                    measurement['C45'] = series.C45
                    measurement['C46'] = series.C46
                    measurement['C51'] = series.C51
                    measurement['C52'] = series.C52
                    measurement['C53'] = series.C53
                    measurement['C54'] = series.C54
                    measurement['C55'] = series.C55
                    measurement['C56'] = series.C56
                    measurement['C61'] = series.C61
                    measurement['C62'] = series.C62
                    measurement['C63'] = series.C63
                    measurement['C64'] = series.C64
                    measurement['C65'] = series.C65
                    measurement['C66'] = series.C66
                    
                    alat_model.append('measurement', measurement)
                proto_model.append('alats', alat_model)
            comp_model.append('prototypes', proto_model)
        ec_model.append('compositions', comp_model)
    
    if new:
        database.add_record(name=record_name, style='PotentialProperties', content=content.xml())
    else:
        database.update_record(record=record, content=content.xml())
